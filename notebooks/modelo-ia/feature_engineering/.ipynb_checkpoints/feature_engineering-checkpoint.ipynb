# %% [markdown]
# <h1 style="text-align:center"> Feature engineering dos dados das aeronaves para a geração do vetor de características e treinamento do modelo</h1>

# %% [markdown]
# ### **Autor:** Luiz Fernando da Silva Borges

# %% [markdown]
# Considerando o contexto da criação de um modelo preditivo para a estimação de falhas em aeronaves, apresenta-se este notebook que evidencia a prototipação de uma pipeline de extração, transformação e carregamento de séries temporais de senores de motores de uma areonave em uma aplicação de auto-ml (Pycaret) com o objetivo de criar técnicas e funções que serão utilizadas para o recorte, pré-processamento e extração de características no pipeline de produção.

# %% [markdown]
# ## 1. Análise da presença de erros em parquets

# %%
import os
import pandas as pd

# %%
# Replace 'folder_path' with the path to your folder containing Parquet files
folder_path = 'flight_data/06120091'

# %%
erros_df = []
not_errors_df = []

failure_column_1 = "message0418DAA-1"
failure_column_2 = "message0422DAA-1"

def detect_failure(dict_counts, failure_code):
    try:
        if dict_counts[failure_code] > 0:
            print("Falha encontrada")
            return True
    except:
            return False

# Loop through files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".parquet"):
        file_path = os.path.join(folder_path, filename)

        #print("\nReading ", filename)
        
        # Read the Parquet file into a DataFrame
        df_flight_data = pd.read_parquet(file_path)

        value_counts_failure_1 = df_flight_data[failure_column_1].value_counts().to_dict()
        value_counts_failure_2 = df_flight_data[failure_column_2].value_counts().to_dict()

        #print(value_counts_failure_1)
        #print(value_counts_failure_2)

        if detect_failure(value_counts_failure_1, 4.0):
            erros_df.append(filename)
        elif detect_failure(value_counts_failure_1, 3.0):
            erros_df.append(filename)
        else:
            not_errors_df.append(filename)
# Out:
# Falha encontrada
# Falha encontrada
# Falha encontrada

# %% [markdown]
# ### Verificação dos arquivos que apresentam erros de um determinado avião

# %%
print("Files containing erros are: ", erros_df)
# Out:
# Files containing erros are:  ['TCRF_ARCHIVE_06120091_20230428193501.parquet', 'TCRF_ARCHIVE_06120091_20230428193502.parquet', 'TCRF_ARCHIVE_06120091_20230515080501.parquet']

# %% [markdown]
# ## 2. Seleção das colunas para análise e exclusão se séries com valores únicos

# %%
filtered_cols = ['recording_time', 'dateDay-1', 'dateMonth-1', 'dateYear-1', 'phaseOfFlight-1',
                 'message0418DAA-1','message0422DAA-1','amscHprsovDrivF-1a', 'amscHprsovDrivF-1b',
                 'amscHprsovDrivF-2b', 'amscPrsovDrivF-1a',
                 'amscPrsovDrivF-1b', 'amscPrsovDrivF-2b',
                 'basBleedLowPressF-1a', 'basBleedLowPressF-2b',
                 'basBleedLowTempF-1a', 'basBleedLowTempF-2b',
                 'basBleedOverPressF-1a', 'basBleedOverPressF-2b',
                 'basBleedOverTempF-1a', 'basBleedOverTempF-2b',
                 'bleedFavTmCmd-1a', 'bleedFavTmCmd-1b',
                 'bleedFavTmCmd-2a', 'bleedFavTmCmd-2b', 'bleedFavTmFbk-1a',
                 'bleedFavTmFbk-1b', 'bleedFavTmFbk-2b', 'bleedHprsovCmdStatus-1a',
                 'bleedHprsovCmdStatus-1b', 'bleedHprsovCmdStatus-2a',
                 'bleedHprsovCmdStatus-2b', 'bleedHprsovOpPosStatus-1a',
                 'bleedHprsovOpPosStatus-1b', 'bleedHprsovOpPosStatus-2a',
                 'bleedHprsovOpPosStatus-2b', 'bleedMonPress-1a',
                 'bleedMonPress-1b', 'bleedMonPress-2a', 'bleedMonPress-2b',
                 'bleedOnStatus-1a', 'bleedOnStatus-1b', 'bleedOnStatus-2b',
                 'bleedOverpressCas-2a', 'bleedOverpressCas-2b',
                 'bleedPrecoolDiffPress-1a', 'bleedPrecoolDiffPress-1b',
                 'bleedPrecoolDiffPress-2a', 'bleedPrecoolDiffPress-2b',
                 'bleedPrsovClPosStatus-1a', 'bleedPrsovClPosStatus-2a',
                 'bleedPrsovFbk-1a']

# %% [markdown]
# ### Declaração de colunas para permanência relativas à timming e mensagens de erro

# %%
columns_keep = ['recording_time', 'dateDay-1', 'dateMonth-1', 'dateYear-1', 'phaseOfFlight-1', 'message0418DAA-1', 'message0422DAA-1']

# %%
def drop_same_value_columns(dataframe, columns_keep):
    columns_to_drop = []

    for col in dataframe.columns:
        if dataframe[col].nunique() == 1 and col not in columns_keep:
            columns_to_drop.append(col)

    if columns_to_drop:
        for col in columns_to_drop:
            print(f"Column {col} will be dropped.")

        dataframe = dataframe.drop(columns=columns_to_drop)
        print(f"{len(columns_to_drop)} columns dropped.")

    return dataframe

# %%
df_failures_selected_list = []

for df_error in erros_df:
    df_flight_failure = pd.read_parquet(folder_path + "/" + df_error)
    df_flight_failure = df_flight_failure[filtered_cols]
    df_flight_failure = drop_same_value_columns(df_flight_failure, columns_keep)
    print(df_flight_failure.head(3))
    df_failures_selected_list.append(df_flight_failure)
# Out:
# Column amscHprsovDrivF-1a will be dropped.
# Column amscHprsovDrivF-1b will be dropped.
# Column amscHprsovDrivF-2b will be dropped.
# Column amscPrsovDrivF-1a will be dropped.
# Column amscPrsovDrivF-1b will be dropped.
# Column amscPrsovDrivF-2b will be dropped.
# Column basBleedLowPressF-1a will be dropped.
# Column basBleedLowPressF-2b will be dropped.
# Column basBleedLowTempF-1a will be dropped.
# Column basBleedLowTempF-2b will be dropped.
# Column basBleedOverPressF-1a will be dropped.
# Column basBleedOverPressF-2b will be dropped.
# Column basBleedOverTempF-1a will be dropped.
# Column basBleedOverTempF-2b will be dropped.
# Column bleedFavTmCmd-2a will be dropped.
# Column bleedFavTmFbk-1a will be dropped.
# Column bleedHprsovCmdStatus-1b will be dropped.
# Column bleedHprsovCmdStatus-2b will be dropped.
# Column bleedHprsovOpPosStatus-1a will be dropped.
# Column bleedHprsovOpPosStatus-1b will be dropped.
# Column bleedHprsovOpPosStatus-2a will be dropped.
# Column bleedHprsovOpPosStatus-2b will be dropped.
# Column bleedOnStatus-1a will be dropped.
# Column bleedOnStatus-1b will be dropped.
# Column bleedOnStatus-2b will be dropped.
# Column bleedOverpressCas-2a will be dropped.
# Column bleedOverpressCas-2b will be dropped.
# Column bleedPrecoolDiffPress-1a will be dropped.
# Column bleedPrecoolDiffPress-2a will be dropped.
# Column bleedPrsovClPosStatus-1a will be dropped.
# Column bleedPrsovClPosStatus-2a will be dropped.
# 31 columns dropped.
#    recording_time  dateDay-1  dateMonth-1  dateYear-1  phaseOfFlight-1  \
# 0               0        NaN          NaN         NaN              0.0
# 1              50        NaN          NaN         NaN              NaN
# 2             100        NaN          NaN         NaN              0.0
#
#    message0418DAA-1  message0422DAA-1  bleedFavTmCmd-1a  bleedFavTmCmd-1b  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN            -512.0           -510.25
# 2               NaN               NaN               NaN               NaN
#
#    bleedFavTmCmd-2b  ...  bleedFavTmFbk-2b  bleedHprsovCmdStatus-1a  \
# 0               NaN  ...               NaN                      0.0
# 1           -511.75  ...           -421.25                      NaN
# 2               NaN  ...               NaN                      1.0
#
#    bleedHprsovCmdStatus-2a  bleedMonPress-1a  bleedMonPress-1b  \
# 0                      1.0               NaN               NaN
# 1                      NaN             320.0             256.0
# 2                      0.0               NaN               NaN
#
#    bleedMonPress-2a  bleedMonPress-2b  bleedPrecoolDiffPress-1b  \
# 0               NaN               NaN                       NaN
# 1            -478.5           434.875                   -70.375
# 2               NaN               NaN                       NaN
#
#    bleedPrecoolDiffPress-2b  bleedPrsovFbk-1a
# 0                       NaN               NaN
# 1                   26.3125             4.375
# 2                       NaN               NaN
#
# [3 rows x 21 columns]
# Column amscHprsovDrivF-1a will be dropped.
# Column amscHprsovDrivF-1b will be dropped.
# Column amscHprsovDrivF-2b will be dropped.
# Column amscPrsovDrivF-1a will be dropped.
# Column amscPrsovDrivF-1b will be dropped.
# Column amscPrsovDrivF-2b will be dropped.
# Column basBleedLowPressF-1a will be dropped.
# Column basBleedLowPressF-2b will be dropped.
# Column basBleedLowTempF-1a will be dropped.
# Column basBleedLowTempF-2b will be dropped.
# Column basBleedOverPressF-1a will be dropped.
# Column basBleedOverPressF-2b will be dropped.
# Column basBleedOverTempF-1a will be dropped.
# Column basBleedOverTempF-2b will be dropped.
# Column bleedFavTmCmd-1a will be dropped.
# Column bleedFavTmCmd-2a will be dropped.
# Column bleedFavTmCmd-2b will be dropped.
# Column bleedFavTmFbk-1a will be dropped.
# Column bleedFavTmFbk-1b will be dropped.
# Column bleedHprsovCmdStatus-1b will be dropped.
# Column bleedHprsovCmdStatus-2b will be dropped.
# Column bleedHprsovOpPosStatus-1a will be dropped.
# Column bleedHprsovOpPosStatus-1b will be dropped.
# Column bleedHprsovOpPosStatus-2a will be dropped.
# Column bleedHprsovOpPosStatus-2b will be dropped.
# Column bleedMonPress-1b will be dropped.
# Column bleedMonPress-2a will be dropped.
# Column bleedMonPress-2b will be dropped.
# Column bleedOnStatus-1a will be dropped.
# Column bleedOnStatus-1b will be dropped.
# Column bleedOnStatus-2b will be dropped.
# Column bleedOverpressCas-2a will be dropped.
# Column bleedOverpressCas-2b will be dropped.
# Column bleedPrecoolDiffPress-1a will be dropped.
# Column bleedPrecoolDiffPress-1b will be dropped.
# Column bleedPrecoolDiffPress-2a will be dropped.
# Column bleedPrsovClPosStatus-1a will be dropped.
# Column bleedPrsovClPosStatus-2a will be dropped.
# 38 columns dropped.
#    recording_time  dateDay-1  dateMonth-1  dateYear-1  phaseOfFlight-1  \
# 0          300050        NaN          NaN         NaN              0.0
# 1          300100        NaN          NaN         NaN              NaN
# 2          300150        NaN          NaN         NaN              0.0
#
#    message0418DAA-1  message0422DAA-1  bleedFavTmCmd-1b  bleedFavTmFbk-2b  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN           -510.75           -420.75
# 2               NaN               NaN               NaN               NaN
#
#    bleedHprsovCmdStatus-1a  bleedHprsovCmdStatus-2a  bleedMonPress-1a  \
# 0                      1.0                      0.0               NaN
# 1                      NaN                      NaN             384.0
# 2                      1.0                      0.0               NaN
#
#    bleedPrecoolDiffPress-2b  bleedPrsovFbk-1a
# 0                       NaN               NaN
# 1                   26.3125             4.375
# 2                       NaN               NaN
# Column amscHprsovDrivF-1a will be dropped.
# Column amscHprsovDrivF-1b will be dropped.
# Column amscHprsovDrivF-2b will be dropped.
# Column amscPrsovDrivF-1a will be dropped.
# Column amscPrsovDrivF-1b will be dropped.
# Column amscPrsovDrivF-2b will be dropped.
# Column basBleedLowPressF-1a will be dropped.
# Column basBleedLowPressF-2b will be dropped.
# Column basBleedLowTempF-1a will be dropped.
# Column basBleedLowTempF-2b will be dropped.
# Column basBleedOverPressF-1a will be dropped.
# Column basBleedOverPressF-2b will be dropped.
# Column basBleedOverTempF-1a will be dropped.
# Column basBleedOverTempF-2b will be dropped.
# Column bleedFavTmCmd-1a will be dropped.
# Column bleedFavTmCmd-2b will be dropped.
# Column bleedFavTmFbk-1a will be dropped.
# Column bleedFavTmFbk-1b will be dropped.
# Column bleedHprsovCmdStatus-1b will be dropped.
# Column bleedHprsovCmdStatus-2b will be dropped.
# Column bleedHprsovOpPosStatus-1a will be dropped.
# Column bleedHprsovOpPosStatus-1b will be dropped.
# Column bleedHprsovOpPosStatus-2a will be dropped.
# Column bleedHprsovOpPosStatus-2b will be dropped.
# Column bleedMonPress-1b will be dropped.
# Column bleedMonPress-2b will be dropped.
# Column bleedOnStatus-1a will be dropped.
# Column bleedOnStatus-1b will be dropped.
# Column bleedOnStatus-2b will be dropped.
# Column bleedOverpressCas-2a will be dropped.
# Column bleedOverpressCas-2b will be dropped.
# Column bleedPrecoolDiffPress-1a will be dropped.
# Column bleedPrecoolDiffPress-1b will be dropped.
# Column bleedPrecoolDiffPress-2a will be dropped.
# Column bleedPrecoolDiffPress-2b will be dropped.
# Column bleedPrsovClPosStatus-1a will be dropped.
# Column bleedPrsovClPosStatus-2a will be dropped.
# 37 columns dropped.
#    recording_time  dateDay-1  dateMonth-1  dateYear-1  phaseOfFlight-1  \
# 0               0        NaN          NaN         NaN              0.0
# 1              50        NaN          NaN         NaN              NaN
# 2             100        NaN          NaN         NaN              0.0
#
#    message0418DAA-1  message0422DAA-1  bleedFavTmCmd-1b  bleedFavTmCmd-2a  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN           -325.25            -442.5
# 2               NaN               NaN               NaN               NaN
#
#    bleedFavTmFbk-2b  bleedHprsovCmdStatus-1a  bleedHprsovCmdStatus-2a  \
# 0               NaN                      0.0                      0.0
# 1           -191.25                      NaN                      NaN
# 2               NaN                      0.0                      0.0
#
#    bleedMonPress-1a  bleedMonPress-2a  bleedPrsovFbk-1a
# 0               NaN               NaN               NaN
# 1           291.625          -478.625            -508.0
# 2               NaN               NaN               NaN

# %% [markdown]
# ## 3. Escolha dos eventos de falha para o corte das épocas do conjunto de dados com falhas e no conjunto de dados sem falhas

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_all_columns(dataframe, num_rows, num_cols, fig_name, red_lines=None, green_lines=None, line_w = 0.5):
    num_plots = len(dataframe.columns)
    plot_index = 0
    
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 15))
    
    for row in range(num_rows):
        for col in range(num_cols):
            if plot_index < num_plots:
                col_name = dataframe.columns[plot_index]
                ax = axes[row, col]
                
                try:
                    ax.plot(dataframe[col_name], marker='o')
                    ax.set_title(f'Line Plot for Column: {col_name}')
                    ax.set_xlabel('Index')
                    ax.set_ylabel(col_name)
                    ax.grid()

                    # Add red vertical lines
                    if red_lines:
                        for line_index in red_lines:
                            ax.axvline(x=line_index, color='red', linestyle='--', linewidth=line_w)

                    # Add green vertical lines
                    if green_lines:
                        for line_index in green_lines:
                            ax.axvline(x=line_index, color='green', linestyle='--', linewidth=0.01)
                except:
                    print(f'Could not plot for column: {col_name}')
                
                plot_index += 1
            else:
                axes[row, col].axis('off')

    plt.savefig(fig_name)
    
    plt.tight_layout()
    plt.show()

# %%
df_number = 1

failure_indexes_3 = []
failure_indexes_4 = []

failure_indexes_3.append(list(df_failures_selected_list[df_number][df_failures_selected_list[df_number][failure_column_1] == 3.0].index))#
failure_indexes_3.append(list(df_failures_selected_list[df_number][df_failures_selected_list[df_number][failure_column_2] == 3.0].index))

failure_indexes_3 = [num for sublist in failure_indexes_3 for num in sublist]

failure_indexes_4.append(list(df_failures_selected_list[df_number][df_failures_selected_list[df_number][failure_column_1] == 4.0].index))
failure_indexes_4.append(list(df_failures_selected_list[df_number][df_failures_selected_list[df_number][failure_column_2] == 4.0].index))

failure_indexes_4 = [num for sublist in failure_indexes_4 for num in sublist]

# %%
print("Índices de falha do tipo 3")
print(failure_indexes_3)
print()

print("Índices de falha do tipo 4")
print(failure_indexes_4)
print()
# Out:
# Índices de falha do tipo 3
# [1023, 1103, 1123, 1143, 1163, 1183, 2363, 2783, 3603, 4003, 4023, 4043, 4303, 4323, 4343, 4363, 4383, 4403, 4783, 4843, 4863, 5643, 7104, 7204, 7224, 7304, 7584, 7604, 7624, 7664, 8324, 8344, 8364, 8384, 8404, 8924, 8964, 8984, 9024, 9084, 9204, 9224, 9284, 9524, 10404, 10424, 10444, 10464, 10504, 10524, 10544, 10584, 10604, 10664, 10844, 10884, 10904, 10924, 12085, 12105, 12125, 12145, 12165, 12185, 12205, 12225, 12245, 12265, 12425, 12445, 12505, 13045, 14145, 14205, 14225, 14245, 14265, 14285, 14425, 15105, 15405, 15485, 15805, 15825, 15845, 15865, 15885, 15905, 15945, 16885, 17125, 17145, 17165, 17185, 17445, 17485, 17505, 17525, 17545, 17565, 18546, 18646, 18706, 18726, 18746, 18766, 18786, 18806, 18906, 18946, 19026, 19046, 19206, 19566, 19586, 19606, 20206, 20326, 20386, 20406, 20426, 20446, 20666, 20746, 20766, 20786, 20806, 20826, 21266, 21966, 22006, 22046, 22086, 22526, 23166, 23186, 23206, 23226, 23246, 23286, 23606, 23626, 23646, 23686, 23706, 23726, 23866, 24167, 24187, 24207, 24227, 24247, 24447, 24487, 24507, 24567, 24587, 25547, 25587, 25707, 25767, 25847, 25867, 25887, 27487, 27707, 27767, 27787, 27807, 27827, 27847, 27867, 27887, 28827, 28987, 29007, 29087, 29107, 29127, 29367]
, 8044, 8064, 8084, 8104, 8124, 8144, 8164, 8184, 8204, 8224, 8244, 8264, 8284, 8304, 8424, 8444, 8464, 8484, 8504, 8524, 8544, 8564, 8584, 8604, 8624, 8644, 8664, 8684, 8704, 8724, 8744, 8764, 8784, 8804, 8824, 8844, 8864, 8884, 8904, 8944, 9004, 9044, 9064, 9104, 9124, 9144, 9164, 9184, 9244, 9264, 9304, 9324, 9344, 9364, 9384, 9404, 9424, 9444, 9464, 9484, 9504, 9544, 9564, 9584, 9604, 9624, 9644, 9664, 9684, 9704, 9724, 9744, 9764, 9784, 9804, 9824, 9844, 9864, 9884, 9904, 9924, 9944, 9964, 9984, 10004, 10024, 10044, 10064, 10084, 10104, 10124, 10144, 10164, 10184, 10204, 10224, 10244, 10264, 10284, 10304, 10324, 10344, 10364, 10384, 10484, 10564, 10624, 10644, 10684, 10704, 10724, 10744, 10764, 10784, 10804, 10824, 10864, 10944, 10964, 10984, 11004, 11024, 11044, 11064, 11084, 11104, 11124, 11144, 11164, 11184, 11204, 11224, 11244, 11264, 11284, 11304, 11324, 11344, 11364, 11384, 11404, 11424, 11444, 11464, 11484, 11504, 11524, 11544, 11564, 11584, 11604, 11624, 11644, 11664, 11684, 11704, 11724, 11744, 11764, 11784, 11804, 11824, 11844, 11864, 11884, 11904, 11924, 11944, 11964, 11984, 12005, 12025, 12045, 12065, 12285, 12305, 12325, 12345, 12365, 12385, 12405, 12465, 12485, 12525, 12545, 12565, 12585, 12605, 12625, 12645, 12665, 12685, 12705, 12725, 12745, 12765, 12785, 12805, 12825, 12845, 12865, 12885, 12905, 12925, 12945, 12965, 12985, 13005, 13025, 13065, 13085, 13105, 13125, 13145, 13165, 13185, 13205, 13225, 13245, 13265, 13285, 13305, 13325, 13345, 13365, 13385, 13405, 13425, 13445, 13465, 13485, 13505, 13525, 13545, 13565, 13585, 13605, 13625, 13645, 13665, 13685, 13705, 13725, 13745, 13765, 13785, 13805, 13825, 13845, 13865, 13885, 13905, 13925, 13945, 13965, 13985, 14005, 14025, 14045, 14065, 14085, 14105, 14125, 14165, 14185, 14305, 14325, 14345, 14365, 14385, 14405, 14445, 144 ...

# %%
# Assuming df_fail_flights is your DataFrame
plot_all_columns(df_failures_selected_list[df_number], 4, 4, "all", red_lines=failure_indexes_3, green_lines=failure_indexes_4, line_w = 0.5)

# %% [markdown]
# ### Escolha dos índices de falha

# %%
failure_indexes = [10000, 20000, 24000]

# %%
plot_all_columns(df_failures_selected_list[df_number], 4, 4, "all", red_lines=failure_indexes, green_lines=[], line_w = 1)

# %% [markdown]
# ### Escolha de um conjunto de dados sem falhas

# %%
baseline_df = pd.read_parquet(folder_path + "/" + not_errors_df[7])
baseline_df = baseline_df[filtered_cols]
baseline_df = drop_same_value_columns(baseline_df, columns_keep)
baseline_df.head(3)
# Out:
# Column amscHprsovDrivF-1a will be dropped.
# Column amscHprsovDrivF-1b will be dropped.
# Column amscHprsovDrivF-2b will be dropped.
# Column amscPrsovDrivF-1a will be dropped.
# Column amscPrsovDrivF-1b will be dropped.
# Column amscPrsovDrivF-2b will be dropped.
# Column basBleedLowPressF-1a will be dropped.
# Column basBleedLowPressF-2b will be dropped.
# Column basBleedLowTempF-1a will be dropped.
# Column basBleedLowTempF-2b will be dropped.
# Column basBleedOverPressF-1a will be dropped.
# Column basBleedOverPressF-2b will be dropped.
# Column basBleedOverTempF-1a will be dropped.
# Column basBleedOverTempF-2b will be dropped.
# Column bleedFavTmCmd-1b will be dropped.
# Column bleedHprsovCmdStatus-1b will be dropped.
# Column bleedOverpressCas-2a will be dropped.
# Column bleedOverpressCas-2b will be dropped.
# 18 columns dropped.
#    recording_time  dateDay-1  dateMonth-1  dateYear-1  phaseOfFlight-1  \
# 0               0        NaN          NaN         NaN              0.0
# 1              50        NaN          NaN         NaN              NaN
# 2             100        NaN          NaN         NaN              0.0
#
#    message0418DAA-1  message0422DAA-1  bleedFavTmCmd-1a  bleedFavTmCmd-2a  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               0.0               0.0
# 2               NaN               NaN               NaN               NaN
#
#    bleedFavTmCmd-2b  ...  bleedOnStatus-1a  bleedOnStatus-1b  \
# 0               NaN  ...               0.0               0.0
# 1               0.0  ...               NaN               NaN
# 2               NaN  ...               0.0               0.0
#
#    bleedOnStatus-2b  bleedPrecoolDiffPress-1a  bleedPrecoolDiffPress-1b  \
# 0               0.0                       NaN                       NaN
# 1               NaN                  -0.03125                   -0.0625
# 2               0.0                       NaN                       NaN
#
#    bleedPrecoolDiffPress-2a  bleedPrecoolDiffPress-2b  \
# 0                       NaN                       NaN
# 1                   0.03125                   0.03125
# 2                       NaN                       NaN
#
#    bleedPrsovClPosStatus-1a  bleedPrsovClPosStatus-2a  bleedPrsovFbk-1a
# 0                       1.0                       1.0               NaN
# 1                       NaN                       NaN               1.5
# 2                       1.0                       1.0               NaN
#
# [3 rows x 34 columns]

# %% [markdown]
# ### Plot do conjunto de dados sem falhas com os índices de análise escolhidos

# %%
plot_all_columns(baseline_df, 4, 4, "all", red_lines=failure_indexes, green_lines=[])

# %% [markdown]
# ## 4. Seleção de épocas 5 minutos antes dos eventos de falha acontecerem

# %%
1/0.05 
20*60*5
# Out:
# 6000

# %% [markdown]
# ### Seleção para o conjunto de falhas

# %%
failure_data = {}
for col in df_failures_selected_list[df_number].columns:
    if "bleed" in col:
        failure_data[col+"_1"] = df_failures_selected_list[df_number][col][failure_indexes[0]-6000:failure_indexes[0]]
        failure_data[col+"_1"] = df_failures_selected_list[df_number][col][failure_indexes[1]-6000:failure_indexes[1]]
        failure_data[col+"_1"] = df_failures_selected_list[df_number][col][failure_indexes[2]-6000:failure_indexes[2]]
        
df_failure_data = pd.DataFrame(failure_data)

df_failure_data.head(7)
# Out:
#        bleedFavTmCmd-1b_1  bleedFavTmFbk-2b_1  bleedHprsovCmdStatus-1a_1  \
# 18000                 NaN                 NaN                        1.0
# 18001                 NaN                 NaN                        NaN
# 18002                 NaN                 NaN                        1.0
# 18003                 NaN                 NaN                        1.0
# 18004             -510.75             -420.75                        NaN
# 18005                 NaN                 NaN                        0.0
# 18006                 NaN                 NaN                        NaN
#
#        bleedHprsovCmdStatus-2a_1  bleedMonPress-1a_1  \
# 18000                        0.0                 NaN
# 18001                        NaN                 NaN
# 18002                        0.0                 NaN
# 18003                        0.0                 NaN
# 18004                        NaN               384.0
# 18005                        0.0                 NaN
# 18006                        NaN                 NaN
#
#        bleedPrecoolDiffPress-2b_1  bleedPrsovFbk-1a_1
# 18000                         NaN                 NaN
# 18001                         NaN                 NaN
# 18002                         NaN                 NaN
# 18003                         NaN                 NaN
# 18004                     26.3125            -507.625
# 18005                         NaN                 NaN
# 18006                         NaN                 NaN

# %% [markdown]
# ### Seleção para o conjunto de não falhas

# %%
non_failure_data = {}
for col in df_failures_selected_list[df_number].columns:
    if "bleed" in col:
        non_failure_data[col+"_1"] = df_failures_selected_list[df_number][col][failure_indexes[0]-1000:failure_indexes[0]+1000]
        non_failure_data[col+"_1"] = df_failures_selected_list[df_number][col][failure_indexes[1]-1000:failure_indexes[1]+1000]
        non_failure_data[col+"_1"] = df_failures_selected_list[df_number][col][failure_indexes[2]-1000:failure_indexes[2]+1000]
        
df_non_failure_data = pd.DataFrame(non_failure_data)

df_non_failure_data.head(7)
# Out:
#        bleedFavTmCmd-1b_1  bleedFavTmFbk-2b_1  bleedHprsovCmdStatus-1a_1  \
# 23000             -510.75             -421.25                        NaN
# 23001                 NaN                 NaN                        1.0
# 23002                 NaN                 NaN                        NaN
# 23003                 NaN                 NaN                        1.0
# 23004             -510.75             -421.25                        NaN
# 23005                 NaN                 NaN                        1.0
# 23006                 NaN                 NaN                        NaN
#
#        bleedHprsovCmdStatus-2a_1  bleedMonPress-1a_1  \
# 23000                        NaN               384.0
# 23001                        0.0                 NaN
# 23002                        NaN                 NaN
# 23003                        0.0                 NaN
# 23004                        NaN               384.0
# 23005                        0.0                 NaN
# 23006                        NaN                 NaN
#
#        bleedPrecoolDiffPress-2b_1  bleedPrsovFbk-1a_1
# 23000                     26.3125            -507.625
# 23001                         NaN                 NaN
# 23002                         NaN                 NaN
# 23003                         NaN                 NaN
# 23004                     26.3125            -507.625
# 23005                         NaN                 NaN
# 23006                         NaN                 NaN

# %% [markdown]
# ### Plot de comparação de épocas para conjunto de dados de falha e não falha

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_columns_from_two_dataframes(df1, df2, column_names, num_rows, num_cols, fig_name, red_lines=None, green_lines=None, line_w=1):
    num_plots = len(column_names)
    
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 15))
    
    for row in range(num_rows):
        for col in range(num_cols):
            if num_plots > 0 and column_names:
                col_name = column_names.pop(0)
                ax = axes[row, col]
                
                try:
                    ax.plot(df1[col_name], marker='o', label='DataFrame 1')
                    ax.plot(df2[col_name], marker='x', label='DataFrame 2')
                    ax.set_title(f'Line Plot for Column: {col_name}')
                    ax.set_xlabel('Index')
                    ax.set_ylabel(col_name)
                    ax.grid()
                    ax.legend()  # Add legend to distinguish between DataFrame 1 and DataFrame 2

                    # Add red vertical lines
                    if red_lines:
                        for line_index in red_lines:
                            ax.axvline(x=line_index, color='red', linestyle='--', linewidth=line_w)

                    # Add green vertical lines
                    if green_lines:
                        for line_index in green_lines:
                            ax.axvline(x=line_index, color='green', linestyle='--', linewidth=0.01)
                except:
                    print(f'Could not plot for column: {col_name}')
                
            else:
                axes[row, col].axis('off')

    plt.savefig(fig_name)
    plt.tight_layout()
    plt.show()

# %%
plot_columns_from_two_dataframes(df_failure_data, df_non_failure_data, df_non_failure_data.columns.tolist(), 3, 3, "combined_plot.png", red_lines=[], green_lines=[])

# %% [markdown]
# ## 5. Fusão dos conjuntos de dados de falha e não falha para o treinamento do modelo

# %% [markdown]
# ### Adição da coluna "label" com o número 1 para representar que cada dado pertence a um conjunto de dados que descrevem uma falha

# %%
df_failure_data["label"] = [1]*len(df_failure_data)
df_failure_data.head(3)
# Out:
#        bleedFavTmCmd-1b_1  bleedFavTmFbk-2b_1  bleedHprsovCmdStatus-1a_1  \
# 18000                 NaN                 NaN                        1.0
# 18001                 NaN                 NaN                        NaN
# 18002                 NaN                 NaN                        1.0
#
#        bleedHprsovCmdStatus-2a_1  bleedMonPress-1a_1  \
# 18000                        0.0                 NaN
# 18001                        NaN                 NaN
# 18002                        0.0                 NaN
#
#        bleedPrecoolDiffPress-2b_1  bleedPrsovFbk-1a_1  label
# 18000                         NaN                 NaN      1
# 18001                         NaN                 NaN      1
# 18002                         NaN                 NaN      1

# %% [markdown]
# ### Adição da coluna "label" com o número 0 para representar que cada dado pertence a um conjunto de dados que não descrevem uma falha

# %%
df_non_failure_data["label"] = [0]*len(df_non_failure_data)
df_non_failure_data.head(3)
# Out:
#        bleedFavTmCmd-1b_1  bleedFavTmFbk-2b_1  bleedHprsovCmdStatus-1a_1  \
# 23000             -510.75             -421.25                        NaN
# 23001                 NaN                 NaN                        1.0
# 23002                 NaN                 NaN                        NaN
#
#        bleedHprsovCmdStatus-2a_1  bleedMonPress-1a_1  \
# 23000                        NaN               384.0
# 23001                        0.0                 NaN
# 23002                        NaN                 NaN
#
#        bleedPrecoolDiffPress-2b_1  bleedPrsovFbk-1a_1  label
# 23000                     26.3125            -507.625      0
# 23001                         NaN                 NaN      0
# 23002                         NaN                 NaN      0

# %% [markdown]
# ### Junção de ambos os cojuntos de dados para a criação do dataframe de treinamento no auto machinne learning Pycaret

# %%
model_combined_df = pd.concat([df_failure_data, df_non_failure_data], axis=0)
model_combined_df.reset_index(drop=True, inplace=True)
model_combined_df.head(7)
# Out:
#    bleedFavTmCmd-1b_1  bleedFavTmFbk-2b_1  bleedHprsovCmdStatus-1a_1  \
# 0                 NaN                 NaN                        1.0
# 1                 NaN                 NaN                        NaN
# 2                 NaN                 NaN                        1.0
# 3                 NaN                 NaN                        1.0
# 4             -510.75             -420.75                        NaN
# 5                 NaN                 NaN                        0.0
# 6                 NaN                 NaN                        NaN
#
#    bleedHprsovCmdStatus-2a_1  bleedMonPress-1a_1  bleedPrecoolDiffPress-2b_1  \
# 0                        0.0                 NaN                         NaN
# 1                        NaN                 NaN                         NaN
# 2                        0.0                 NaN                         NaN
# 3                        0.0                 NaN                         NaN
# 4                        NaN               384.0                     26.3125
# 5                        0.0                 NaN                         NaN
# 6                        NaN                 NaN                         NaN
#
#    bleedPrsovFbk-1a_1  label
# 0                 NaN      1
# 1                 NaN      1
# 2                 NaN      1
# 3                 NaN      1
# 4            -507.625      1
# 5                 NaN      1
# 6                 NaN      1

# %% [markdown]
# ### Verificação da fusão dos dados

# %%
model_combined_df.tail(7)
# Out:
#       bleedFavTmCmd-1b_1  bleedFavTmFbk-2b_1  bleedHprsovCmdStatus-1a_1  \
# 7993             -510.75             -420.75                        NaN
# 7994                 NaN                 NaN                        1.0
# 7995                 NaN                 NaN                        NaN
# 7996                 NaN                 NaN                        1.0
# 7997             -510.75             -420.25                        NaN
# 7998                 NaN                 NaN                        1.0
# 7999                 NaN                 NaN                        NaN
#
#       bleedHprsovCmdStatus-2a_1  bleedMonPress-1a_1  \
# 7993                        NaN               384.0
# 7994                        0.0                 NaN
# 7995                        NaN                 NaN
# 7996                        0.0                 NaN
# 7997                        NaN               384.0
# 7998                        0.0                 NaN
# 7999                        NaN                 NaN
#
#       bleedPrecoolDiffPress-2b_1  bleedPrsovFbk-1a_1  label
# 7993                     26.3125            -507.625      0
# 7994                         NaN                 NaN      0
# 7995                         NaN                 NaN      0
# 7996                         NaN                 NaN      0
# 7997                     26.3125            -507.625      0
# 7998                         NaN                 NaN      0
# 7999                         NaN                 NaN      0

# %% [markdown]
# ## 6. Classificação

# %%
from pycaret.classification import *

# %% [markdown]
# ### Treinamento de classificadores com os dados crus

# %%
# Initialize PyCaret setup
exp = setup(model_combined_df, target='label')

# Compare and evaluate different models
compare_models()
# Out:
# <style type="text/css">
# #T_8dc02_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8dc02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dc02_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8dc02_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dc02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8dc02_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8dc02_row0_col1" class="data row0 col1" >5014</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8dc02_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8dc02_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8dc02_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8dc02_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8dc02_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_8dc02_row3_col1" class="data row3 col1" >(8000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8dc02_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_8dc02_row4_col1" class="data row4 col1" >(8000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8dc02_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_8dc02_row5_col1" class="data row5 col1" >(5600, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8dc02_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_8dc02_row6_col1" class="data row6 col1" >(2400, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8dc02_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_8dc02_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8dc02_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_8dc02_row8_col1" class="data row8 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8dc02_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_8dc02_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8dc02_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_8dc02_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8dc02_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_8dc02_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8dc02_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_8dc02_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8dc02_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_8dc02_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8dc02_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_8dc02_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8dc02_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_8dc02_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8dc02_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_8dc02_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8dc02_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_8dc02_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8dc02_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_8dc02_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8dc02_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8dc02_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_8dc02_row19_col1" class="data row19 col1" >20b7</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bd45e th {
#   text-align: left;
# }
# #T_bd45e_row0_col0, #T_bd45e_row0_col2, #T_bd45e_row0_col3, #T_bd45e_row0_col5, #T_bd45e_row1_col0, #T_bd45e_row1_col1, #T_bd45e_row1_col2, #T_bd45e_row1_col3, #T_bd45e_row1_col4, #T_bd45e_row1_col5, #T_bd45e_row1_col6, #T_bd45e_row1_col7, #T_bd45e_row2_col0, #T_bd45e_row2_col1, #T_bd45e_row2_col2, #T_bd45e_row2_col3, #T_bd45e_row2_col4, #T_bd45e_row2_col5, #T_bd45e_row2_col6, #T_bd45e_row2_col7, #T_bd45e_row3_col0, #T_bd45e_row3_col1, #T_bd45e_row3_col2, #T_bd45e_row3_col3, #T_bd45e_row3_col4, #T_bd45e_row3_col6, #T_bd45e_row3_col7, #T_bd45e_row4_col0, #T_bd45e_row4_col1, #T_bd45e_row4_col2, #T_bd45e_row4_col3, #T_bd45e_row4_col4, #T_bd45e_row4_col5, #T_bd45e_row4_col6, #T_bd45e_row4_col7, #T_bd45e_row5_col0, #T_bd45e_row5_col1, #T_bd45e_row5_col2, #T_bd45e_row5_col3, #T_bd45e_row5_col4, #T_bd45e_row5_col5, #T_bd45e_row5_col6, #T_bd45e_row5_col7, #T_bd45e_row6_col0, #T_bd45e_row6_col1, #T_bd45e_row6_col2, #T_bd45e_row6_col3, #T_bd45e_row6_col4, #T_bd45e_row6_col5, #T_bd45e_row6_col6, #T_bd45e_row6_col7, #T_bd45e_row7_col0, #T_bd45e_row7_col1, #T_bd45e_row7_col2, #T_bd45e_row7_col3, #T_bd45e_row7_col4, #T_bd45e_row7_col5, #T_bd45e_row7_col6, #T_bd45e_row7_col7, #T_bd45e_row8_col0, #T_bd45e_row8_col1, #T_bd45e_row8_col2, #T_bd45e_row8_col3, #T_bd45e_row8_col4, #T_bd45e_row8_col5, #T_bd45e_row8_col6, #T_bd45e_row8_col7, #T_bd45e_row9_col0, #T_bd45e_row9_col1, #T_bd45e_row9_col2, #T_bd45e_row9_col3, #T_bd45e_row9_col4, #T_bd45e_row9_col5, #T_bd45e_row9_col6, #T_bd45e_row9_col7, #T_bd45e_row10_col0, #T_bd45e_row10_col1, #T_bd45e_row10_col2, #T_bd45e_row10_col3, #T_bd45e_row10_col4, #T_bd45e_row10_col5, #T_bd45e_row10_col6, #T_bd45e_row10_col7, #T_bd45e_row11_col0, #T_bd45e_row11_col1, #T_bd45e_row11_col3, #T_bd45e_row11_col4, #T_bd45e_row11_col5, #T_bd45e_row11_col6, #T_bd45e_row11_col7, #T_bd45e_row12_col0, #T_bd45e_row12_col1, #T_bd45e_row12_col2, #T_bd45e_row12_col4, #T_bd45e_row12_col5, #T_bd45e_row12_col6, #T_bd45e_row12_col7, #T_bd45e_row13_col0, #T_bd45e_row13_col1, #T_bd45e_row13_col2, #T_bd45e_row13_col3, #T_bd45e_row13_col4, #T_bd45e_row13_col5, #T_bd45e_row13_col6, #T_bd45e_row13_col7 {
#   text-align: left;
# }
# #T_bd45e_row0_col1, #T_bd45e_row0_col4, #T_bd45e_row0_col6, #T_bd45e_row0_col7, #T_bd45e_row3_col5, #T_bd45e_row11_col2, #T_bd45e_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bd45e_row0_col8, #T_bd45e_row1_col8, #T_bd45e_row2_col8, #T_bd45e_row3_col8, #T_bd45e_row4_col8, #T_bd45e_row6_col8, #T_bd45e_row7_col8, #T_bd45e_row8_col8, #T_bd45e_row9_col8, #T_bd45e_row10_col8, #T_bd45e_row11_col8, #T_bd45e_row12_col8, #T_bd45e_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bd45e_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bd45e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd45e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bd45e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_bd45e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_bd45e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_bd45e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_bd45e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_bd45e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_bd45e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_bd45e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd45e_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_bd45e_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_bd45e_row0_col1" class="data row0 col1" >0.7787</td>
#       <td id="T_bd45e_row0_col2" class="data row0 col2" >0.6354</td>
#       <td id="T_bd45e_row0_col3" class="data row0 col3" >0.9755</td>
#       <td id="T_bd45e_row0_col4" class="data row0 col4" >0.7830</td>
#       <td id="T_bd45e_row0_col5" class="data row0 col5" >0.8687</td>
#       <td id="T_bd45e_row0_col6" class="data row0 col6" >0.2167</td>
#       <td id="T_bd45e_row0_col7" class="data row0 col7" >0.2849</td>
#       <td id="T_bd45e_row0_col8" class="data row0 col8" >0.6820</td>
#     </tr>
#     <tr>
#       <th id="T_bd45e_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_bd45e_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_bd45e_row1_col1" class="data row1 col1" >0.7784</td>
#       <td id="T_bd45e_row1_col2" class="data row1 col2" >0.5809</td>
#       <td id="T_bd45e_row1_col3" class="data row1 col3" >0.9755</td>
#       <td id="T_bd45e_row1_col4" class="data row1 col4" >0.7827</td>
#       <td id="T_bd45e_row1_col5" class="data row1 col5" >0.8685</td>
#       <td id="T_bd45e_row1_col6" class="data row1 col6" >0.2151</td>
#       <td id="T_bd45e_row1_col7" class="data row1 col7" >0.2833</td>
#       <td id="T_bd45e_row1_col8" class="data row1 col8" >0.6170</td>
#     </tr>
#     <tr>
#       <th id="T_bd45e_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_bd45e_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_bd45e_row2_col1" class="data row2 col1" >0.7784</td>
#       <td id="T_bd45e_row2_col2" class="data row2 col2" >0.6281</td>
#       <td id="T_bd45e_row2_col3" class="data row2 col3" >0.9762</td>
#       <td id="T_bd45e_row2_col4" class="data row2 col4" >0.7824</td>
#       <td id="T_bd45e_row2_col5" class="data row2 col5" >0.8686</td>
#       <td id="T_bd45e_row2_col6" class="data row2 col6" >0.2137</td>
#       <td id="T_bd45e_row2_col7" class="data row2 col7" >0.2834</td>
#       <td id="T_bd45e_row2_col8" class="data row2 col8" >0.6730</td>
#     </tr>
#     <tr>
#       <th id="T_bd45e_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_bd45e_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_bd45e_row3_col1" class="data row3 col1" >0.7770</td>
#       <td id="T_bd45e_row3_col2" class="data row3 col2" >0.6342</td>
#       <td id="T_bd45e_row3_col3" class="data row3 col3" >0.9936</td>
#       <td id="T_bd45e_row3_col4" class="data row3 col4" >0.7736</td>
#       <td id="T_bd45e_row3_col5" class="data row3 col5" >0.8698</td>
#       <td id="T_bd45e_row3_col6" class="data row3 col6" >0.1679</td>
#       <td id="T_bd45e_row3_col7" class="data row3 col7" >0.2776</td>
#       <td id="T_bd45e_row3_col8" class="data row3 col8" >1.1650</td>
#     </tr>
#     <tr>
#       <th id="T_bd45e_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_bd45e_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_bd45e_row4_col1" class="data row4 col1" >0.7766</td>
#       <td id="T_bd45e_row4_col2" class="data row4 col2" >0.6190</td>
#       <td id="T_bd45e_row4_col3" class="data row4 col3" >0.9771</td>
#       <td id="T_bd45e_row4_col4" class="data row4 col4" >0.7804</td>
#       <td id="T_bd45e_row4_col5" class="data row4 col5" >0.8677</td>
#       <td id="T_bd45e_row4_col6" class="data row4 col6" >0.2030</td>
#       <td id="T_bd45e_row4_col7" class="data row4 col7" >0.2763</td>
#       <td id="T_bd45e_row4_col8" class="data row4 col8" >0.6590</td>
#     </tr>
#     <tr>
#       <th id="T_bd45e_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_bd45e_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_bd45e_row5_col1" class="data row5 col1" >0.7759</td>
#       <td id="T_bd45e_row5_col2" class="data row5 col2" >0.6303</td>
#       <td id="T_bd45e_row5_col3" class="data row5 col3" >0.9798</td>
#       <td id="T_bd45e_row5_col4" class="data row5 col4" >0.7787</td>
#       <td id="T_bd45e_row5_col5" class="data row5 col5" >0.8677</td>
#       <td id="T_bd45e_row5_col6" class="data row5 col6" >0.1931</td>
#       <td id="T_bd45e_row5_col7" class="data row5 col7" >0.2724</td>
#       <td id="T_bd45
# LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)

# %%
trainning_results_raw = pull()

# %% [markdown]
# ### Treinamento de classificadores considerando a eliminação de valores NaNs

# %%
pre_processed = model_combined_df.fillna(0, inplace=False)

# %%
exp_1 = setup(pre_processed, target='label')

# Compare and evaluate different models
compare_models()
# Out:
# <style type="text/css">
# #T_4ab23_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_
level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_74249_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_74249_row4_col1" class="data row4 col1" >0.7791</td>
#       <td id="T_74249_row4_col2" class="data row4 col2" >0.6423</td>
#       <td id="T_74249_row4_col3" class="data row4 col3" >0.9974</td>
#       <td id="T_74249_row4_col4" class="data row4 col4" >0.7736</td>
#       <td id="T_74249_row4_col5" class="data row4 col5" >0.8714</td>
#       <td id="T_74249_row4_col6" class="data row4 col6" >0.1710</td>
#       <td id="T_74249_row4_col7" class="data row4 col7" >0.2946</td>
#       <td id="T_74249_row4_col8" class="data row4 col8" >0.7680</td>
#     </tr>
#     <tr>
#       <th id="T_74249_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_74249_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_74249_row5_col1" class="data row5 col1" >0.7786</td>
#       <td id="T_74249_row5_col2" class="data row5 col2" >0.6379</td>
#       <td id="T_74249_row5_col3" class="data row5 col3" >0.9967</td>
#       <td id="T_74249_row5_col4" class="data row5 col4" >0.7735</td>
#       <td id="T_74249_row5_col5" class="data row5 col5" >0.8710</td>
#       <td id="T_74249_row5_col6" class="data row5 col6" >0.1699</td>
#       <td id="T_74249_row5_col7" class="data row5 col7" >0.2907</td>
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        random_state=2650, splitter='best')

# %%
trainning_results_raw_zeros = pull()

# %% [markdown]
# ### Treinamento de classificadores considerando a normalização dos valores dos sensores

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming your DataFrame is named 'df'
scaler = MinMaxScaler()
pre_processed_normalized = pd.DataFrame(scaler.fit_transform(pre_processed), columns=pre_processed.columns)

# %%
pre_processed_normalized.tail()
# Out:
#       bleedFavTmCmd-1b_1  bleedFavTmFbk-2b_1  bleedHprsovCmdStatus-1a_1  \
# 7995                 1.0            1.000000                        0.0
# 7996                 1.0            1.000000                        1.0
# 7997                 0.0            0.002374                        0.0
# 7998                 1.0            1.000000                        1.0
# 7999                 1.0            1.000000                        0.0
#
#       bleedHprsovCmdStatus-2a_1  bleedMonPress-1a_1  \
# 7995                        0.0                 0.0
# 7996                        0.0                 0.0
# 7997                        0.0                 1.0
# 7998                        0.0                 0.0
# 7999                        0.0                 0.0
#
#       bleedPrecoolDiffPress-2b_1  bleedPrsovFbk-1a_1  label
# 7995                         0.0            0.991455    0.0
# 7996                         0.0            0.991455    0.0
# 7997                         1.0            0.000000    0.0
# 7998                         0.0            0.991455    0.0
# 7999                         0.0            0.991455    0.0

# %%
exp_1 = setup(pre_processed_normalized, target='label')

# Compare and evaluate different models
compare_models()
# Out:
# <style type="text/css">
# #T_f7e51_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f7e51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7e51_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f7e51_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7e51_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7e51_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f7e51_row0_col1" class="data row0 col1" >4022</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7e51_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f7e51_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7e51_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f7e51_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7e51_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f7e51_row3_col1" class="data row3 col1" >(8000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7e51_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f7e51_row4_col1" class="data row4 col1" >(8000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7e51_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f7e51_row5_col1" class="data row5 col1" >(5600, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7e51_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f7e51_row6_col1" class="data row6 col1" >(2400, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f7e51_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f7e51_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f7e51_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f7e51_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f7e51_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f7e51_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f7e51_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f7e51_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f7e51_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f7e51_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f7e51_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_f7e51_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f7e51_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f7e51_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_
row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_2fae5_row3_col1" class="data row3 col1" >0.7793</td>
#       <td id="T_2fae5_row3_col2" class="data row3 col2" >0.6521</td>
#       <td id="T_2fae5_row3_col3" class="data row3 col3" >0.9919</td>
#       <td id="T_2fae5_row3_col4" class="data row3 col4" >0.7761</td>
#       <td id="T_2fae5_row3_col5" class="data row3 col5" >0.8708</td>
#       <td id="T_2fae5_row3_col6" class="data row3 col6" >0.1841</td>
#       <td id="T_2fae5_row3_col7" class="data row3 col7" >0.2930</td>
#       <td id="T_2fae5_row3_col8" class="data row3 col8" >0.7620</td>
#     </tr>
#     <tr>
#       <th id="T_2fae5_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_2fae5_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_2fae5_row4_col1" class="data row4 col1" >0.7789</td>
#       <td id="T_2fae5_row4_col2" class="data row4 col2" >0.6526</td>
#       <td id="T_2fae5_row4_col3" class="data row4 col3" >0.9898</td>
#       <td id="T_2fae5_row4_col4" class="data row4 col4" >0.7768</td>
#       <td id="T_2fae5_row4_col5" class="data row4 col5" >0.8704</td>
#       <td id="T_2fae5_row4_col6" class="data row4 col6" >0.1869</td>
#       <td id="T_2fae5_row4_col7" class="data row4 col7" >0.2905</td>
#       <td id="T_2fae5_row4_col8" class="data row4 col8" >0.6640</td>
#     </tr>
#     <tr>
#       <th id="T_2fae5_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_2fae5_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_2fae5_row5_col1" class="data row5 col1" >0.7789</td>
#       <td id="T_2fae5_row5_col2" class="data row5 col2" >0.6526</td>
#       <td id="T_2fae5_row5_col3" class="data row5 col3" >0.9898</td>
#       <td id="T_2fae5_row5_col4" class="data row5 col4" >0.7768</td>
#       <td id="T_2fae5_row5_col5" class="data row5 col5" >0.8704</td>
#       <td id="T_2fae5_row5_col6" class="data row5 col6" >0.1869</td>
#       <td id="T_2fae5_row5_col7" class="data row5 col7" >0.2905</td
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
trainning_results_raw_zeros_norm = pull()

# %% [markdown]
# ### Treinamento de classificadores considerando a aplicação de uma média móvel sobre os valores normalizados

# %%
window_size = 4000

# Create a list of columns to include in the rolling operation (excluding "label")
columns_to_include = pre_processed_normalized.columns.difference(['label'])

# Apply the rolling mean to selected columns
pre_processed_normalized_ma = pre_processed_normalized[columns_to_include].rolling(window=window_size).mean()

# The first 3999 rows will have NaN values because the window is not fully covered
# You may want to drop those rows if they are not needed
pre_processed_normalized_ma = pre_processed_normalized_ma.dropna()

# Add the "label" column back to the DataFrame
pre_processed_normalized_ma['label'] = pre_processed_normalized['label']

# %%
pre_processed_normalized_ma.tail()
# Out:
#       bleedFavTmCmd-1b_1  bleedFavTmFbk-2b_1  bleedHprsovCmdStatus-1a_1  \
# 7995             0.75001            0.750084                    0.39825
# 7996             0.75026            0.750334                    0.39850
# 7997             0.75001            0.750084                    0.39825
# 7998             0.75001            0.750084                    0.39850
# 7999             0.75001            0.750084                    0.39825
#
#       bleedHprsovCmdStatus-2a_1  bleedMonPress-1a_1  \
# 7995                      0.043            0.235750
# 7996                      0.043            0.235542
# 7997                      0.043            0.235792
# 7998                      0.043            0.235792
# 7999                      0.043            0.235792
#
#       bleedPrecoolDiffPress-2b_1  bleedPrsovFbk-1a_1  label
# 7995                    0.249998            0.805341    0.0
# 7996                    0.249748            0.805589    0.0
# 7997                    0.249998            0.805341    0.0
# 7998                    0.249998            0.805341    0.0
# 7999                    0.249998            0.805341    0.0

# %% [markdown]
# ### Verificação de redução de dimensionalidade pós média móvel

# %%
print(len(pre_processed_normalized_ma))
print(len(pre_processed_normalized))
# Out:
# 4001
# 8000

# %%
exp_1 = setup(pre_processed_normalized_ma, target='label')
# Out:
# <style type="text/css">
# #T_b6db7_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b6db7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6db7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b6db7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6db7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6db7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b6db7_row0_col1" class="data row0 col1" >4806</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6db7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b6db7_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6db7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b6db7_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6db7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b6db7_row3_col1" class="data row3 col1" >(4001, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6db7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b6db7_row4_col1" class="data row4 col1" >(4001, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b6db7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b6db7_row5_col1" class="data row5 col1" >(2800, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b6db7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b6db7_row6_col1" class="data row6 col1" >(1201, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b6db7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b6db7_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b6db7_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b6db7_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b6db7_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b6db7_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b6db7_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b6db7_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b6db7_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b6db7_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b6db7_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_b6db7_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b6db7_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_b6db7_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b6db7_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_b6db7_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b6db7_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_b6db7_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b6db7_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_b6db7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b6db7_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_b6db7_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b6db7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b6db7_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_b6db7_row18_col1" class="data row18 col1" >2f78</td>
#     </tr>
#   </tbody>
# </table>

# %%
trainning_results_raw_zeros_norm_ma = pull()

# %% [markdown]
# # 7. Comparação geral da acurácia gerada pelo treinamento dos diferentes modelos alimentados por diferentes técnicas de pré-processamento e extração de caracterísiticas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def generate_grouped_bar_chart(df1, df2, df3, df4, group_labels):
    # Extract the first three models and accuracy values from each dataframe
    models = df1['Model'].head(3).tolist()
    accuracy_df1 = df1['Accuracy'].head(3).tolist()
    accuracy_df2 = df2['Accuracy'].head(3).tolist()
    accuracy_df3 = df3['Accuracy'].head(3).tolist()
    accuracy_df4 = df4['Accuracy'].head(3).tolist()
    
    # Set the width of the bars and the positions for each group
    bar_width = 0.2
    index = np.arange(len(models))
    
    # Create subplots
    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Plot bars for each dataframe with their respective custom labels
    for i, df in enumerate([df1, df2, df3, df4]):
        ax.bar(index + i * bar_width, df['Accuracy'].head(3).tolist(), bar_width, label=group_labels[i])
    
    # Set labels, title, and legend
    ax.set_xlabel('Models')
    ax.set_ylabel('Accuracy')
    ax.set_title('Grouped Bar Chart')
    ax.set_xticks(index + bar_width * 1.5)
    ax.set_xticklabels(models)
    ax.legend()
    
    # Show the plot
    plt.tight_layout()
    plt.show()

# %%
# Example usage:
group_labels = ['Sem tratamento', 'Remoção de NaNs', 'Normalização', 'Média móvel']
generate_grouped_bar_chart(trainning_results_raw, trainning_results_raw_zeros,
                           trainning_results_raw_zeros_norm, trainning_results_raw_zeros_norm_ma,
                           group_labels)

# %% [markdown]
# # 8. Discussão

# %% [markdown]
# Embora o resultado para a criação de alguns classificadores tenham apresentado alta acurácia, ainda é necessário avaliar se isto não se deve a uma possível sobreajuste do modelo aos dados de treinamento. Portanto, é essencial realizar uma validação rigorosa por meio de técnicas como a validação cruzada, para verificar a capacidade do classificador de generalizar seu desempenho para dados não vistos. Além disso, a interpretação dos resultados deve considerar métricas além da acurácia, como precisão, recall, F1-score e matriz de confusão, para obter uma compreensão mais completa do desempenho do modelo em diferentes aspectos, especialmente em situações de desequilíbrio de classes. É crucial adotar uma abordagem holística na avaliação de modelos de machine learning, visando não apenas à alta acurácia, mas também à sua capacidade de fazer previsões robustas e confiáveis em cenários do mundo real.
