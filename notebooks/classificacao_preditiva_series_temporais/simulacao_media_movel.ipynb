# %% [markdown]
# <center> <h1> Seleção de parquets correspondentes a trecho e anterioridade a falhas e a não falhas</h1> </center>

# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import random


def generate_random_data(file_name, total_lines, num_columns, lines_per_file):
    # Create a list of column names
    column_names = []
    for i in range(1, num_columns + 1):
        column_names.append(f"sensor_{i}")
    
    # Initialize a counter for file names
    file_counter = 1
    
    # Generate random lines and save them into separate Parquet files
    current_line = 0
    while current_line < total_lines:
        # Determine how many lines to generate for this file
        lines_to_generate = min(lines_per_file, total_lines - current_line)
        
        # Create a dictionary for data
        data = {}
        for col in column_names:
            data[col] = []
            for _ in range(lines_to_generate):
                data[col].append(random.random())
        
        # Create a dataframe with random data
        df = pd.DataFrame(data)
        
        # Save the dataframe as a Parquet file
        table = pa.Table.from_pandas(df)
        filename = f'{file_name}_{file_counter}.parquet'
        pq.write_table(table, filename)
        
        # Increment the file counter and update the current_line count
        file_counter += 1
        current_line += lines_to_generate
    
    print(f"{file_counter - 1} Parquet files have been generated.")

    return

# %% [markdown]
# ### Geração de parquets de falhas correspondentes ao período de uma semana

# %%
failure_file_name = "falha"
failure_total_lines = 3_000_000 #30_000_000 for all the files that are in our Drive
failure_num_columns = 8
failure_lines_per_file = 1_000_000  # You can adjust this as needed

#generate_random_data(failure_file_name, failure_total_lines, failure_num_columns, failure_lines_per_file)

# %% [markdown]
# ### Geração de parquets de não falha correspondentes ao período de uma semana

# %%
non_failure_file_name = "nao_falha"
non_failure_total_lines = 3_000_000 #30_000_000 for all the files that are in our Drive
non_failure_num_columns = 8
non_failure_lines_per_file = 1_000_000  # You can adjust this as needed

#generate_random_data(non_failure_file_name, non_failure_total_lines, non_failure_num_columns, non_failure_lines_per_file)

# %% [markdown]
# ### Implementação da função de média móvel

# %%
import pandas as pd

def moving_average(df, column_names, window_size):
    """
    Calculate the moving average for specified columns in a DataFrame.

    Parameters:
    - df: pandas DataFrame
        The input DataFrame.
    - column_names: list of str
        The column names for which moving averages will be calculated.
    - window_size: int
        The size of the moving average window.

    Returns:
    - pandas DataFrame
        A new DataFrame with the same columns as the input, including moving average columns.
    """
    result_df =  pd.DataFrame()

    # Calculate moving averages for each specified column
    for column in column_names:
        result_df[f'{column}_moving_avg'] = df[column].rolling(window=window_size).mean()

    result_df.dropna(inplace=True)
    result_df.reset_index(drop=True, inplace=True)

    return result_df

# %% [markdown]
# ### Verificação de dimensão do dataframe antes da aplicação da média móvel

# %%
df_cru_falha = pd.read_parquet("falha_1.parquet")
df_cru_falha.head()
# Out:
#    sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  sensor_6  sensor_7  \
# 0  0.180437  0.543236  0.058747  0.641238  0.456573  0.152388  0.398071
# 1  0.797652  0.166190  0.183609  0.070591  0.814511  0.439338  0.587446
# 2  0.988906  0.737004  0.442120  0.950468  0.928465  0.945063  0.172777
# 3  0.756042  0.967428  0.315361  0.089875  0.517460  0.683760  0.052969
# 4  0.120998  0.035749  0.973682  0.457801  0.217553  0.741013  0.748934
#
#    sensor_8
# 0  0.505388
# 1  0.890407
# 2  0.839158
# 3  0.112268
# 4  0.759808

# %%
df_cru_falha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   sensor_1  1000000 non-null  float64
#  1   sensor_2  1000000 non-null  float64
#  2   sensor_3  1000000 non-null  float64
#  3   sensor_4  1000000 non-null  float64
#  4   sensor_5  1000000 non-null  float64
#  5   sensor_6  1000000 non-null  float64
#  6   sensor_7  1000000 non-null  float64
#  7   sensor_8  1000000 non-null  float64
# dtypes: float64(8)
# memory usage: 61.0 MB

# %% [markdown]
# ### Função que recebe um conjunto de parquets e retorna um dataframe contendo a média móvel de todos eles concatenados

# %%
def dataframe_moving_average(file_names, column_names, window_size):
    
    moving_average_total_df = pd.DataFrame()
    
    for file_name in file_names:
        
        temp_dataframe = pd.read_parquet(file_name)
    
        moving_average_temp_dataframe = moving_average(temp_dataframe, column_names, window_size)
    
        print(file_name)
        print(moving_average_temp_dataframe.head(3))
        print("-------------------------------------------------------------------------------\n")
    
        moving_average_total_df = pd.concat([moving_average_total_df, moving_average_temp_dataframe], ignore_index=True)
    
        return moving_average_total_df

# %%
failure_files = ["falha_1.parquet", "falha_2.parquet", "falha_3.parquet"]
failure_column_names = ["sensor_1",	"sensor_2",	"sensor_3",	"sensor_4",	"sensor_5",	"sensor_6",	"sensor_7",	"sensor_8"]
window_size = 500_000

# %% [markdown]
# ### Aplicação da função de média móvel para todos os parquets de falha

# %%
total_failure_moving_average = dataframe_moving_average(failure_files, failure_column_names, window_size)
# Out:
# falha_1.parquet
#    sensor_1_moving_avg  sensor_2_moving_avg  sensor_3_moving_avg  \
# 0             0.499472             0.500254             0.500461
# 1             0.499472             0.500255             0.500461
# 2             0.499472             0.500256             0.500462
#
#    sensor_4_moving_avg  sensor_5_moving_avg  sensor_6_moving_avg  \
# 0             0.499855             0.500409             0.499935
# 1             0.499855             0.500408             0.499936
# 2             0.499857             0.500408             0.499937
#
#    sensor_7_moving_avg  sensor_8_moving_avg
# 0             0.499887             0.499807
# 1             0.499888             0.499807
# 2             0.499887             0.499807
# -------------------------------------------------------------------------------

# %%
total_failure_moving_average.head(3)
# Out:
#    sensor_1_moving_avg  sensor_2_moving_avg  sensor_3_moving_avg  \
# 0             0.499472             0.500254             0.500461
# 1             0.499472             0.500255             0.500461
# 2             0.499472             0.500256             0.500462
#
#    sensor_4_moving_avg  sensor_5_moving_avg  sensor_6_moving_avg  \
# 0             0.499855             0.500409             0.499935
# 1             0.499855             0.500408             0.499936
# 2             0.499857             0.500408             0.499937
#
#    sensor_7_moving_avg  sensor_8_moving_avg
# 0             0.499887             0.499807
# 1             0.499888             0.499807
# 2             0.499887             0.499807

# %%
total_failure_moving_average.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500001 entries, 0 to 500000
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   sensor_1_moving_avg  500001 non-null  float64
#  1   sensor_2_moving_avg  500001 non-null  float64
#  2   sensor_3_moving_avg  500001 non-null  float64
#  3   sensor_4_moving_avg  500001 non-null  float64
#  4   sensor_5_moving_avg  500001 non-null  float64
#  5   sensor_6_moving_avg  500001 non-null  float64
#  6   sensor_7_moving_avg  500001 non-null  float64
#  7   sensor_8_moving_avg  500001 non-null  float64
# dtypes: float64(8)
# memory usage: 30.5 MB

# %% [markdown]
# ### Aplicação da função de média móvel para todos os parquets de não falha

# %%
non_failure_files = ["nao_falha_1.parquet", "nao_falha_2.parquet", "nao_falha_3.parquet"]
non_failure_column_names = ["sensor_1",	"sensor_2",	"sensor_3",	"sensor_4",	"sensor_5",	"sensor_6",	"sensor_7",	"sensor_8"]
window_size = 500_000

# %%
total_non_failure_moving_average = dataframe_moving_average(non_failure_files, non_failure_column_names, window_size)
# Out:
# nao_falha_1.parquet
#    sensor_1_moving_avg  sensor_2_moving_avg  sensor_3_moving_avg  \
# 0             0.500135             0.499956             0.500434
# 1             0.500134             0.499955             0.500433
# 2             0.500132             0.499957             0.500433
#
#    sensor_4_moving_avg  sensor_5_moving_avg  sensor_6_moving_avg  \
# 0             0.499399             0.500705             0.499995
# 1             0.499400             0.500705             0.499994
# 2             0.499401             0.500705             0.499996
#
#    sensor_7_moving_avg  sensor_8_moving_avg
# 0             0.499860             0.499485
# 1             0.499860             0.499485
# 2             0.499859             0.499486
# -------------------------------------------------------------------------------

# %%
total_non_failure_moving_average.head(3)

# %%
total_non_failure_moving_average.info()

# %% [markdown]
# ### Identificação dos dataframes com etiquetas de falha (1) e não falha (0)

# %%
total_failure_moving_average["label"] = [1]*len(total_non_failure_moving_average)
total_failure_moving_average.head(7)
# Out:
#    sensor_1_moving_avg  sensor_2_moving_avg  sensor_3_moving_avg  \
# 0             0.499472             0.500254             0.500461
# 1             0.499472             0.500255             0.500461
# 2             0.499472             0.500256             0.500462
# 3             0.499471             0.500257             0.500463
# 4             0.499471             0.500256             0.500464
# 5             0.499472             0.500257             0.500464
# 6             0.499472             0.500259             0.500464
#
#    sensor_4_moving_avg  sensor_5_moving_avg  sensor_6_moving_avg  \
# 0             0.499855             0.500409             0.499935
# 1             0.499855             0.500408             0.499936
# 2             0.499857             0.500408             0.499937
# 3             0.499855             0.500407             0.499936
# 4             0.499857             0.500408             0.499936
# 5             0.499857             0.500409             0.499936
# 6             0.499857             0.500410             0.499936
#
#    sensor_7_moving_avg  sensor_8_moving_avg  label
# 0             0.499887             0.499807      1
# 1             0.499888             0.499807      1
# 2             0.499887             0.499807      1
# 3             0.499887             0.499807      1
# 4             0.499888             0.499807      1
# 5             0.499889             0.499808      1
# 6             0.499889             0.499809      1

# %%
total_non_failure_moving_average["label"] = [0]*len(total_non_failure_moving_average)
total_non_failure_moving_average.head(7)
# Out:
#    sensor_1_moving_avg  sensor_2_moving_avg  sensor_3_moving_avg  \
# 0             0.500135             0.499956             0.500434
# 1             0.500134             0.499955             0.500433
# 2             0.500132             0.499957             0.500433
# 3             0.500133             0.499956             0.500433
# 4             0.500132             0.499956             0.500431
# 5             0.500131             0.499956             0.500431
# 6             0.500130             0.499957             0.500433
#
#    sensor_4_moving_avg  sensor_5_moving_avg  sensor_6_moving_avg  \
# 0             0.499399             0.500705             0.499995
# 1             0.499400             0.500705             0.499994
# 2             0.499401             0.500705             0.499996
# 3             0.499400             0.500704             0.499996
# 4             0.499400             0.500703             0.499996
# 5             0.499400             0.500703             0.499994
# 6             0.499398             0.500704             0.499995
#
#    sensor_7_moving_avg  sensor_8_moving_avg  label
# 0             0.499860             0.499485      0
# 1             0.499860             0.499485      0
# 2             0.499859             0.499486      0
# 3             0.499860             0.499485      0
# 4             0.499859             0.499486      0
# 5             0.499859             0.499487      0
# 6             0.499858             0.499487      0

# %% [markdown]
# ### Fusão dos dataframes com as médias móveis totais de uma semana de dados coletada uma semana anterior a um evento de falha e o mesmo para não falha

# %%
trainning_df = pd.concat([total_failure_moving_average, total_non_failure_moving_average], ignore_index=True)

# %%
trainning_df.head(7)
# Out:
#    sensor_1_moving_avg  sensor_2_moving_avg  sensor_3_moving_avg  \
# 0             0.499472             0.500254             0.500461
# 1             0.499472             0.500255             0.500461
# 2             0.499472             0.500256             0.500462
# 3             0.499471             0.500257             0.500463
# 4             0.499471             0.500256             0.500464
# 5             0.499472             0.500257             0.500464
# 6             0.499472             0.500259             0.500464
#
#    sensor_4_moving_avg  sensor_5_moving_avg  sensor_6_moving_avg  \
# 0             0.499855             0.500409             0.499935
# 1             0.499855             0.500408             0.499936
# 2             0.499857             0.500408             0.499937
# 3             0.499855             0.500407             0.499936
# 4             0.499857             0.500408             0.499936
# 5             0.499857             0.500409             0.499936
# 6             0.499857             0.500410             0.499936
#
#    sensor_7_moving_avg  sensor_8_moving_avg  label
# 0             0.499887             0.499807      1
# 1             0.499888             0.499807      1
# 2             0.499887             0.499807      1
# 3             0.499887             0.499807      1
# 4             0.499888             0.499807      1
# 5             0.499889             0.499808      1
# 6             0.499889             0.499809      1

# %%
trainning_df.tail(7)
# Out:
#          sensor_1_moving_avg  sensor_2_moving_avg  sensor_3_moving_avg  \
# 999995              0.500926             0.499974             0.499675
# 999996              0.500926             0.499975             0.499675
# 999997              0.500926             0.499975             0.499676
# 999998              0.500927             0.499975             0.499676
# 999999              0.500927             0.499974             0.499676
# 1000000             0.500926             0.499973             0.499675
# 1000001             0.500927             0.499974             0.499675
#
#          sensor_4_moving_avg  sensor_5_moving_avg  sensor_6_moving_avg  \
# 999995              0.500581             0.500241             0.500515
# 999996              0.500581             0.500240             0.500514
# 999997              0.500580             0.500241             0.500513
# 999998              0.500580             0.500242             0.500513
# 999999              0.500581             0.500242             0.500514
# 1000000             0.500581             0.500242             0.500513
# 1000001             0.500581             0.500241             0.500512
#
#          sensor_7_moving_avg  sensor_8_moving_avg  label
# 999995              0.499867             0.499606      0
# 999996              0.499868             0.499606      0
# 999997              0.499869             0.499607      0
# 999998              0.499868             0.499606      0
# 999999              0.499867             0.499606      0
# 1000000             0.499867             0.499606      0
# 1000001             0.499866             0.499606      0

# %% [markdown]
# ### Treinamento do classificador

# %%
from pycaret.classification import *

# %%
experiment_model_1_week = setup(trainning_df, target='label')

# Compare and evaluate different models
best_model_1_week = compare_models()
# Out:
# <style type="text/css">
# #T_2839c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2839c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2839c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2839c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2839c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2839c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2839c_row0_col1" class="data row0 col1" >3441</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2839c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2839c_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2839c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2839c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2839c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2839c_row3_col1" class="data row3 col1" >(1000002, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2839c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2839c_row4_col1" class="data row4 col1" >(1000002, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2839c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2839c_row5_col1" class="data row5 col1" >(700001, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2839c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2839c_row6_col1" class="data row6 col1" >(300001, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2839c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_2839c_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2839c_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_2839c_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2839c_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_2839c_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2839c_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_2839c_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2839c_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_2839c_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2839c_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_2839c_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2839c_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_2839c_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2839c_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_2839c_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2839c_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_2839c_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2839c_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_2839c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2839c_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_2839c_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2839c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2839c_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_2839c_row18_col1" class="data row18 col1" >f660</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_391a9 th {
#   text-align: left;
# }
# #T_391a9_row0_col0, #T_391a9_row1_col0, #T_391a9_row2_col0, #T_391a9_row3_col0, #T_391a9_row3_col2, #T_391a9_row4_col0, #T_391a9_row5_col0, #T_391a9_row6_col0, #T_391a9_row7_col0, #T_391a9_row8_col0, #T_391a9_row9_col0, #T_391a9_row10_col0, #T_391a9_row10_col1, #T_391a9_row10_col3, #T_391a9_row10_col4, #T_391a9_row10_col5, #T_391a9_row10_col6, #T_391a9_row10_col7, #T_391a9_row11_col0, #T_391a9_row11_col1, #T_391a9_row11_col3, #T_391a9_row11_col5, #T_391a9_row11_col6, #T_391a9_row11_col7, #T_391a9_row12_col0, #T_391a9_row12_col1, #T_391a9_row12_col2, #T_391a9_row12_col3, #T_391a9_row12_col4, #T_391a9_row12_col5, #T_391a9_row12_col6, #T_391a9_row12_col7, #T_391a9_row13_col0, #T_391a9_row13_col1, #T_391a9_row13_col2, #T_391a9_row13_col3, #T_391a9_row13_col4, #T_391a9_row13_col5, #T_391a9_row13_col6, #T_391a9_row13_col7 {
#   text-align: left;
# }
# #T_391a9_row0_col1, #T_391a9_row0_col2, #T_391a9_row0_col3, #T_391a9_row0_col4, #T_391a9_row0_col5, #T_391a9_row0_col6, #T_391a9_row0_col7, #T_391a9_row1_col1, #T_391a9_row1_col2, #T_391a9_row1_col3, #T_391a9_row1_col4, #T_391a9_row1_col5, #T_391a9_row1_col6, #T_391a9_row1_col7, #T_391a9_row2_col1, #T_391a9_row2_col2, #T_391a9_row2_col3, #T_391a9_row2_col4, #T_391a9_row2_col5, #T_391a9_row2_col6, #T_391a9_row2_col7, #T_391a9_row3_col1, #T_391a9_row3_col3, #T_391a9_row3_col4, #T_391a9_row3_col5, #T_391a9_row3_col6, #T_391a9_row3_col7, #T_391a9_row4_col1, #T_391a9_row4_col2, #T_391a9_row4_col3, #T_391a9_row4_col4, #T_391a9_row4_col5, #T_391a9_row4_col6, #T_391a9_row4_col7, #T_391a9_row5_col1, #T_391a9_row5_col2, #T_391a9_row5_col3, #T_391a9_row5_col4, #T_391a9_row5_col5, #T_391a9_row5_col6, #T_391a9_row5_col7, #T_391a9_row6_col1, #T_391a9_row6_col2, #T_391a9_row6_col3, #T_391a9_row6_col4, #T_391a9_row6_col5, #T_391a9_row6_col6, #T_391a9_row6_col7, #T_391a9_row7_col1, #T_391a9_row7_col2, #T_391a9_row7_col3, #T_391a9_row7_col4, #T_391a9_row7_col5, #T_391a9_row7_col6, #T_391a9_row7_col7, #T_391a9_row8_col1, #T_391a9_row8_col2, #T_391a9_row8_col3, #T_391a9_row8_col4, #T_391a9_row8_col5, #T_391a9_row8_col6, #T_391a9_row8_col7, #T_391a9_row9_col1, #T_391a9_row9_col2, #T_391a9_row9_col3, #T_391a9_row9_col4, #T_391a9_row9_col5, #T_391a9_row9_col6, #T_391a9_row9_col7, #T_391a9_row10_col2, #T_391a9_row11_col2, #T_391a9_row11_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_391a9_row0_col8, #T_391a9_row1_col8, #T_391a9_row2_col8, #T_391a9_row3_col8, #T_391a9_row4_col8, #T_391a9_row5_col8, #T_391a9_row6_col8, #T_391a9_row7_col8, #T_391a9_row8_col8, #T_391a9_row9_col8, #T_391a9_row10_col8, #T_391a9_row11_col8, #T_391a9_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_391a9_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_391a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_391a9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_391a9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_391a9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_391a9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_391a9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_391a9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_391a9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_391a9_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_391a9_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_391a9_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_391a9_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_391a9_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_391a9_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_391a9_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_391a9_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_391a9_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_391a9_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_391a9_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_391a9_row0_col8" class="data row0 col8" >0.8750</td>
#     </tr>
#     <tr>
#       <th id="T_391a9_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_391a9_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_391a9_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_391a9_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_391a9_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_391a9_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_391a9_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_391a9_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_391a9_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_391a9_row1_col8" class="data row1 col8" >2.7970</td>
#     </tr>
#     <tr>
#       <th id="T_391a9_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_391a9_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_391a9_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_391a9_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_391a9_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_391a9_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_391a9_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_391a9_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_391a9_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_391a9_row2_col8" class="data row2 col8" >0.4800</td>
#     </tr>
#     <tr>
#       <th id="T_391a9_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_391a9_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_391a9_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_391a9_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_391a9_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_391a9_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_391a9_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_391a9_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_391a9_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_391a9_row3_col8" class="data row3 col8" >0.3550</td>
#     </tr>
#     <tr>
#       <th id="T_391a9_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_391a9_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_391a9_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_391a9_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_391a9_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_391a9_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_391a9_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_391a9_row4_col6" class="data row4 col6" >1.0000</td>
#       <td id="T_391a9_row4_col7" class="data row4 col7" >1.0000</td>
#       <td id="T_391a9_row4_col8" class="data row4 col8" >9.4060</td>
#     </tr>
#     <tr>
#       <th id="T_391a9_level0_row5" class="row_heading level0 row5" >qda</th>
#       <td id="T_391a9_row5_col0" class="data row5 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_391a9_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_391a9_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_391a9_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_391a9_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_391a9_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_391a9_row5_col6" class="data row5 col6" >1.0000</td>
#       <td id="T_391a9_row5_col7" class="data row5 col7" >1.0000</td>
#       <td id="T_3

# %%
trainning_results_1_week_df = pull()

# %%
final_model_1_week = create_model(best_model_1_week)
# Out:
# <style type="text/css">
# #T_f7749_row10_col0, #T_f7749_row10_col1, #T_f7749_row10_col2, #T_f7749_row10_col3, #T_f7749_row10_col4, #T_f7749_row10_col5, #T_f7749_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f7749">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7749_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f7749_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f7749_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f7749_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f7749_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f7749_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f7749_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7749_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7749_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_f7749_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_f7749_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_f7749_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_f7749_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_f7749_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_f7749_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7749_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_f7749_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_f7749_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_f7749_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_f7749_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_f7749_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_f7749_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7749_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_f7749_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_f7749_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_f7749_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_f7749_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_f7749_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_f7749_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7749_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_f7749_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_f7749_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_f7749_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_f7749_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_f7749_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_f7749_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7749_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_f7749_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_f7749_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_f7749_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_f7749_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_f7749_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_f7749_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7749_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_f7749_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_f7749_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_f7749_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_f7749_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_f7749_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_f7749_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7749_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_f7749_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_f7749_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_f7749_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_f7749_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_f7749_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_f7749_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f7749_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_f7749_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_f7749_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_f7749_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_f7749_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_f7749_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_f7749_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f7749_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_f7749_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_f7749_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_f7749_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_f7749_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_f7749_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_f7749_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f7749_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_f7749_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_f7749_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_f7749_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_f7749_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_f7749_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_f7749_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f7749_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_f7749_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_f7749_row10_col2" class="data row10 col2" >1.0000</td>
#       <td id="T_f7749_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_f7749_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_f7749_row10_col5" class="data row10 col5" >1.0000</td>
#       <td id="T_f7749_row10_col6" class="data row10 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f7749_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f7749_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_f7749_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_f7749_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_f7749_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_f7749_row11_col4

# %%
save_model(final_model_1_week, model_name='failure_1_week', model_only=True)
# Out:
# Model Successfully Saved
# (LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                     intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                     multi_class='auto', n_jobs=None, penalty='l2',
#                     random_state=3441, solver='lbfgs', tol=0.0001, verbose=0,
#                     warm_start=False),
#  'failure_1_week.pkl')
