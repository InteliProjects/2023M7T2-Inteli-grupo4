# %%
import os
import pandas as pd

# %%
def read_parquet_files(folder_path):
    parquet_files = [file for file in os.listdir(folder_path) if file.endswith('.parquet')]

    if not parquet_files:
        print("No Parquet files found in the specified folder.")
        return None
    
    dataframes = []
    
    for file in parquet_files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_parquet(file_path)
        print("File: {} | Shape: {}".format(file, df.shape))
        dataframes.append(df)
    
    combined_df = pd.concat(dataframes, ignore_index=True)
    
    return combined_df

folder_name = "airplane_data_083"
flights_combined_data_083 = read_parquet_files(folder_name)
# Out:
# File: TCRF_ARCHIVE_06120083_20221226053232.parquet | Shape: (141381, 93)
# File: TCRF_ARCHIVE_06120083_20221226103930.parquet | Shape: (78941, 93)
# File: TCRF_ARCHIVE_06120083_20221226133230.parquet | Shape: (81781, 93)
# File: TCRF_ARCHIVE_06120083_20221227214831.parquet | Shape: (77581, 93)
# File: TCRF_ARCHIVE_06120083_20221227234931.parquet | Shape: (88961, 93)
# File: TCRF_ARCHIVE_06120083_20221228044833.parquet | Shape: (179461, 93)
# File: TCRF_ARCHIVE_06120083_20221229195901.parquet | Shape: (10101, 93)
# File: TCRF_ARCHIVE_06120083_20221229195902.parquet | Shape: (91641, 93)
# File: TCRF_ARCHIVE_06120083_20230102143801.parquet | Shape: (29821, 93)
# File: TCRF_ARCHIVE_06120083_20230102143802.parquet | Shape: (15101, 93)
# File: TCRF_ARCHIVE_06120083_20230102143803.parquet | Shape: (185361, 93)
# File: TCRF_ARCHIVE_06120083_20230102174731.parquet | Shape: (140701, 93)
# File: TCRF_ARCHIVE_06120083_20230103153831.parquet | Shape: (91761, 93)
# File: TCRF_ARCHIVE_06120083_20230104045632.parquet | Shape: (161181, 93)
# File: TCRF_ARCHIVE_06120083_20230110192932.parquet | Shape: (99001, 93)
# File: TCRF_ARCHIVE_06120083_20230110230231.parquet | Shape: (71121, 93)

# %%
flights_combined_data_083
# Out:
#          recording_time  aircraftSerNum-1  amscChBasHealthStatus-1b
# 0                     0               NaN                       NaN  \
# 1                    50               NaN                       0.0
# 2                   100               NaN                       NaN
# 3                   150           20083.0                       NaN
# 4                   200               NaN                       NaN
# ...                 ...               ...                       ...
# 1543891         3555800               NaN                       0.0
# 1543892         3555850               NaN                       NaN
# 1543893         3555900               NaN                       NaN
# 1543894         3555950               NaN                       NaN
# 1543895         3556000               NaN                       0.0
#
#          amscChBasHealthStatus-1a  amscChBasHealthStatus-2b
# 0                             NaN                       NaN  \
# 1                             0.0                       0.0
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 1543891                       0.0                       0.0
# 1543892                       NaN                       NaN
# 1543893                       NaN                       NaN
# 1543894                       NaN                       NaN
# 1543895                       0.0                       0.0
#
#          amscHprsovDrivF-1a  amscHprsovDrivF-1b  amscHprsovDrivF-2b
# 0                       NaN                 NaN                 NaN  \
# 1                       0.0                 0.0                 0.0
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 1543891                 0.0                 0.0                 0.0
# 1543892                 NaN                 NaN                 NaN
# 1543893                 NaN                 NaN                 NaN
# 1543894                 NaN                 NaN                 NaN
# 1543895                 0.0                 0.0                 0.0
#
#          amscPrsovDrivF-1a  amscPrsovDrivF-1b  ...  message0418DAA-1
# 0                      NaN                NaN  ...               NaN  \
# 1                      0.0                0.0  ...               NaN
# 2                      NaN                NaN  ...               NaN
# 3                      NaN                NaN  ...               0.0
# 4                      NaN                NaN  ...               NaN
# ...                    ...                ...  ...               ...
# 1543891                0.0                0.0  ...               NaN
# 1543892                NaN                NaN  ...               NaN
# 1543893                NaN                NaN  ...               NaN
# 1543894                NaN                NaN  ...               NaN
# 1543895                0.0                0.0  ...               NaN
#
#          message0422DAA-1  messageInhibitPhases-1  phaseOfFlight-1
# 0                     NaN                     1.0              0.0  \
# 1                     NaN                     NaN              NaN
# 2                     NaN                     1.0              0.0
# 3                     0.0                     NaN              NaN
# 4                     NaN                     1.0              0.0
# ...                   ...                     ...              ...
# 1543891               NaN                     NaN              NaN
# 1543892               NaN                     1.0              0.0
# 1543893               NaN                     NaN              NaN
# 1543894               NaN                     1.0              0.0
# 1543895               NaN                     NaN              NaN
#
#          phaseOfFlightNavigation-1  sfyBasFaultWord1Bit13-1a
# 0                              2.0                       NaN  \
# 1                              NaN                       0.0
# 2                              2.0                       NaN
# 3                              NaN                       NaN
# 4                              2.0                       NaN
# ...                            ...                       ...
# 1543891                        NaN                       0.0
# 1543892                        2.0                       NaN
# 1543893                        NaN                       NaN
# 1543894                        2.0                       NaN
# 1543895                        NaN                       0.0
#
#          sfyBasFaultWord1Bit13-2b  timeHours-1  timeMinutes-1  timeSeconds-1
# 0                             NaN          NaN            NaN            NaN
# 1                             0.0          NaN            NaN            NaN
# 2                             NaN          NaN            NaN            NaN
# 3                             NaN          3.0           29.0           59.0
# 4                             NaN          NaN            NaN            NaN
# ...                           ...          ...            ...            ...
# 1543891                       0.0          NaN            NaN            NaN
# 1543892                       NaN          NaN            NaN            NaN
# 1543893                       NaN          NaN            NaN            NaN
# 1543894                       NaN          NaN            NaN            NaN
# 1543895                       0.0          NaN            NaN            NaN
#
# [1543896 rows x 93 columns]

# %%
flights_combined_data_083.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1543896 entries, 0 to 1543895
# Data columns (total 93 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   recording_time                1543896 non-null  int64
#  1   aircraftSerNum-1              77189 non-null    float64
#  2   amscChBasHealthStatus-1b      385915 non-null   float64
#  3   amscChBasHealthStatus-1a      385915 non-null   float64
#  4   amscChBasHealthStatus-2b      385915 non-null   float64
#  5   amscHprsovDrivF-1a            385915 non-null   float64
#  6   amscHprsovDrivF-1b            385915 non-null   float64
#  7   amscHprsovDrivF-2b            385915 non-null   float64
#  8   amscPrsovDrivF-1a             385915 non-null   float64
#  9   amscPrsovDrivF-1b             385915 non-null   float64
#  10  amscPrsovDrivF-2b             385915 non-null   float64
#  11  basBleedLowPressF-1a          385915 non-null   float64
#  12  basBleedLowPressF-2b          385915 non-null   float64
#  13  basBleedLowTempF-1a           385915 non-null   float64
#  14  basBleedLowTempF-2b           385915 non-null   float64
#  15  basBleedOverPressF-1a         385915 non-null   float64
#  16  basBleedOverPressF-2b         385915 non-null   float64
#  17  basBleedOverTempF-1a          385915 non-null   float64
#  18  basBleedOverTempF-2b          385915 non-null   float64
#  19  bleedAcsBleedConfigStatus-1b  772075 non-null   float64
#  20  bleedAcsBleedConfigStatus-2b  772075 non-null   float64
#  21  bleedFavTmCmd-1a              385915 non-null   float64
#  22  bleedFavTmCmd-1b              385915 non-null   float64
#  23  bleedFavTmCmd-2a              385915 non-null   float64
#  24  bleedFavTmCmd-2b              385915 non-null   float64
#  25  bleedFavTmFbk-1a              385915 non-null   float64
#  26  bleedFavTmFbk-1b              385915 non-null   float64
#  27  bleedFavTmFbk-2b              385915 non-null   float64
#  28  bleedHprsovCmdStatus-1a       772075 non-null   float64
#  29  bleedHprsovCmdStatus-1b       772075 non-null   float64
#  30  bleedHprsovCmdStatus-2a       772075 non-null   float64
#  31  bleedHprsovCmdStatus-2b       772075 non-null   float64
#  32  bleedHprsovOpPosStatus-1a     772075 non-null   float64
#  33  bleedHprsovOpPosStatus-1b     772075 non-null   float64
#  34  bleedHprsovOpPosStatus-2a     772075 non-null   float64
#  35  bleedHprsovOpPosStatus-2b     772075 non-null   float64
#  36  bleedMonPress-1a              385915 non-null   float64
#  37  bleedMonPress-1b              385915 non-null   float64
#  38  bleedMonPress-2a              385915 non-null   float64
#  39  bleedMonPress-2b              385915 non-null   float64
#  40  bleedOnStatus-1a              772075 non-null   float64
#  41  bleedOnStatus-1b              772075 non-null   float64
#  42  bleedOnStatus-2b              772075 non-null   float64
#  43  bleedOutTemp-1a               385915 non-null   float64
#  44  bleedOutTemp-1b               385915 non-null   float64
#  45  bleedOutTemp-2a               385915 non-null   float64
#  46  bleedOutTemp-2b               385915 non-null   float64
#  47  bleedOutTempTarget-1a         385915 non-null   float64
#  48  bleedOutTempTarget-1b         385915 non-null   float64
#  49  bleedOutTempTarget-2b         385915 non-null   float64
#  50  bleedOverpressCas-1a          385915 non-null   float64
#  51  bleedOverpressCas-2a          385915 non-null   float64
#  52  bleedOverpressCas-2b          385915 non-null   float64
#  53  bleedPrecoolDiffPress-1a      385915 non-null   float64
#  54  bleedPrecoolDiffPress-1b      385915 non-null   float64
#  55  bleedPrecoolDiffPress-2a      385915 non-null   float64
#  56  bleedPrecoolDiffPress-2b      385915 non-null   float64
#  57  bleedPrsovClPosStatus-1a      772075 non-null   float64
#  58  bleedPrsovClPosStatus-2a      772075 non-null   float64
#  59  bleedPrsovFbk-1a              385915 non-null   float64
#  60  bleedPrsovFbk-1b              385915 non-null   float64
#  61  bleedPrsovFbk-2b              385915 non-null   float64
#  62  bleedPrsovOpPosStatus-1a      772075 non-null   float64
#  63  bleedPrsovOpPosStatus-1b      772075 non-null   float64
#  64  bleedPrsovOpPosStatus-2a      772075 non-null   float64
#  65  bleedPrsovOpPosStatus-2b      772075 non-null   float64
#  66  bleedPrsovTmCmd-1a            385915 non-null   float64
#  67  bleedPrsovTmCmd-1b            385915 non-null   float64
#  68  bleedPrsovTmCmd-2a            385915 non-null   float64
#  69  bleedPrsovTmCmd-2b            385915 non-null   float64
#  70  bleedSingleOperation-1a       772075 non-null   float64
#  71  bleedSingleOperation-2b       772075 non-null   float64
#  72  bleedSwPress-1a               385915 non-null   float64
#  73  bleedSwPress-1b               385915 non-null   float64
#  74  bleedSwPress-2a               385915 non-null   float64
#  75  bleedSwPress-2b               385915 non-null   float64
#  76  correctedCoreSpeed-1a         1543896 non-null  float64
#  77  correctedCoreSpeed-3a         1543896 non-null  float64
#  78  correctedN1Speed-1a           1543896 non-null  float64
#  79  correctedN1Speed-3a           1543896 non-null  float64
#  80  dateDay-1                     77189 non-null    float64
#  81  dateMonth-1                   77189 non-null    float64
#  82  dateYear-1                    77189 non-null    float64
#  83  message0418DAA-1              77189 non-null    float64
#  84  message0422DAA-1              77189 non-null    float64
#  85  messageInhibitPhases-1        772075 non-null   float64
#  86  phaseOfFlight-1               772075 non-null   float64
#  87  phaseOfFlightNavigation-1     772075 non-null   float64
#  88  sfyBasFaultWord1Bit13-1a      385915 non-null   float64
#  89  sfyBasFaultWord1Bit13-2b      385915 non-null   float64
#  90  timeHours-1                   77189 non-null    float64
#  91  timeMinutes-1                 77189 non-null    float64
#  92  timeSeconds-1                 77189 non-null    float64
# dtypes: float64(92), int64(1)
# memory usage: 1.1 GB

# %%
flights_combined_data_083.describe()
# Out:
#        recording_time  aircraftSerNum-1  amscChBasHealthStatus-1b
# count    1.543896e+06           77189.0                  385915.0  \
# mean     3.110275e+06           20083.0                       0.0
# std      2.220861e+06               0.0                       0.0
# min      0.000000e+00           20083.0                       0.0
# 25%      1.288450e+06           20083.0                       0.0
# 50%      2.757400e+06           20083.0                       0.0
# 75%      4.408150e+06           20083.0                       0.0
# max      9.268000e+06           20083.0                       0.0
#
#        amscChBasHealthStatus-1a  amscChBasHealthStatus-2b  amscHprsovDrivF-1a
# count                  385915.0                  385915.0            385915.0  \
# mean                        0.0                       0.0                 0.0
# std                         0.0                       0.0                 0.0
# min                         0.0                       0.0                 0.0
# 25%                         0.0                       0.0                 0.0
# 50%                         0.0                       0.0                 0.0
# 75%                         0.0                       0.0                 0.0
# max                         0.0                       0.0                 0.0
#
#        amscHprsovDrivF-1b  amscHprsovDrivF-2b  amscPrsovDrivF-1a
# count            385915.0            385915.0           385915.0  \
# mean                  0.0                 0.0                0.0
# std                   0.0                 0.0                0.0
# min                   0.0                 0.0                0.0
# 25%                   0.0                 0.0                0.0
# 50%                   0.0                 0.0                0.0
# 75%                   0.0                 0.0                0.0
# max                   0.0                 0.0                0.0
#
#        amscPrsovDrivF-1b  ...  message0418DAA-1  message0422DAA-1
# count           385915.0  ...           77189.0           77189.0  \
# mean                 0.0  ...               0.0               0.0
# std                  0.0  ...               0.0               0.0
# min                  0.0  ...               0.0               0.0
# 25%                  0.0  ...               0.0               0.0
# 50%                  0.0  ...               0.0               0.0
# 75%                  0.0  ...               0.0               0.0
# max                  0.0  ...               0.0               0.0
#
#        messageInhibitPhases-1  phaseOfFlight-1  phaseOfFlightNavigation-1
# count           772075.000000    772075.000000              772075.000000  \
# mean                 4.301985         0.873945                   4.379603
# std                  1.395046         0.801437                   1.529984
# min                  0.000000         0.000000                   1.000000
# 25%                  5.000000         0.000000                   3.000000
# 50%                  5.000000         1.000000                   5.000000
# 75%                  5.000000         2.000000                   5.000000
# max                  6.000000         2.000000                   7.000000
#
#        sfyBasFaultWord1Bit13-1a  sfyBasFaultWord1Bit13-2b   timeHours-1
# count                  385915.0                  385915.0  77189.000000  \
# mean                        0.0                       0.0     12.226535
# std                         0.0                       0.0      6.850407
# min                         0.0                       0.0      2.000000
# 25%                         0.0                       0.0      4.000000
# 50%                         0.0                       0.0     13.000000
# 75%                         0.0                       0.0     18.000000
# max                         0.0                       0.0     23.000000
#
#        timeMinutes-1  timeSeconds-1
# count   77189.000000   77189.000000
# mean       28.853528      29.499372
# std        17.039439      17.308384
# min         0.000000       0.000000
# 25%        14.000000      15.000000
# 50%        28.000000      30.000000
# 75%        43.000000      44.000000
# max        59.000000      59.000000
#
# [8 rows x 93 columns]

# %%
# Sugestão: Destacar e deixar bem claro o motivo pelo qual essas colunas foram selecionadas e alguma que chamou mais atenção
filtered_cols = ['recording_time', 'dateDay-1', 'dateMonth-1', 'dateYear-1', 'phaseOfFlight-1',
                 'message0418DAA-1','message0422DAA-1','amscHprsovDrivF-1a', 'amscHprsovDrivF-1b',
                 'amscHprsovDrivF-2b', 'amscPrsovDrivF-1a',
                 'amscPrsovDrivF-1b', 'amscPrsovDrivF-2b',
                 'basBleedLowPressF-1a', 'basBleedLowPressF-2b',
                 'basBleedLowTempF-1a', 'basBleedLowTempF-2b',
                 'basBleedOverPressF-1a', 'basBleedOverPressF-2b',
                 'basBleedOverTempF-1a', 'basBleedOverTempF-2b',
                 'bleedFavTmCmd-1a', 'bleedFavTmCmd-1b',
                 'bleedFavTmCmd-2a', 'bleedFavTmCmd-2b', 'bleedFavTmFbk-1a',
                 'bleedFavTmFbk-1b', 'bleedFavTmFbk-2b', 'bleedHprsovCmdStatus-1a',
                 'bleedHprsovCmdStatus-1b', 'bleedHprsovCmdStatus-2a',
                 'bleedHprsovCmdStatus-2b', 'bleedHprsovOpPosStatus-1a',
                 'bleedHprsovOpPosStatus-1b', 'bleedHprsovOpPosStatus-2a',
                 'bleedHprsovOpPosStatus-2b', 'bleedMonPress-1a',
                 'bleedMonPress-1b', 'bleedMonPress-2a', 'bleedMonPress-2b',
                 'bleedOnStatus-1a', 'bleedOnStatus-1b', 'bleedOnStatus-2b',
                 'bleedOverpressCas-2a', 'bleedOverpressCas-2b',
                 'bleedPrecoolDiffPress-1a', 'bleedPrecoolDiffPress-1b',
                 'bleedPrecoolDiffPress-2a', 'bleedPrecoolDiffPress-2b',
                 'bleedPrsovClPosStatus-1a', 'bleedPrsovClPosStatus-2a',
                 'bleedPrsovFbk-1a']
                 
print(len(filtered_cols))
# Out:
# 52

# %%
def select_columns_and_combine(dataframe, column_names):
    selected_df = dataframe[column_names]
    return selected_df


flights_combined_data_083 = select_columns_and_combine(flights_combined_data_083, filtered_cols)

# %%
flights_combined_data_083.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1543896 entries, 0 to 1543895
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   recording_time             1543896 non-null  int64
#  1   dateDay-1                  77189 non-null    float64
#  2   dateMonth-1                77189 non-null    float64
#  3   dateYear-1                 77189 non-null    float64
#  4   phaseOfFlight-1            772075 non-null   float64
#  5   message0418DAA-1           77189 non-null    float64
#  6   message0422DAA-1           77189 non-null    float64
#  7   amscHprsovDrivF-1a         385915 non-null   float64
#  8   amscHprsovDrivF-1b         385915 non-null   float64
#  9   amscHprsovDrivF-2b         385915 non-null   float64
#  10  amscPrsovDrivF-1a          385915 non-null   float64
#  11  amscPrsovDrivF-1b          385915 non-null   float64
#  12  amscPrsovDrivF-2b          385915 non-null   float64
#  13  basBleedLowPressF-1a       385915 non-null   float64
#  14  basBleedLowPressF-2b       385915 non-null   float64
#  15  basBleedLowTempF-1a        385915 non-null   float64
#  16  basBleedLowTempF-2b        385915 non-null   float64
#  17  basBleedOverPressF-1a      385915 non-null   float64
#  18  basBleedOverPressF-2b      385915 non-null   float64
#  19  basBleedOverTempF-1a       385915 non-null   float64
#  20  basBleedOverTempF-2b       385915 non-null   float64
#  21  bleedFavTmCmd-1a           385915 non-null   float64
#  22  bleedFavTmCmd-1b           385915 non-null   float64
#  23  bleedFavTmCmd-2a           385915 non-null   float64
#  24  bleedFavTmCmd-2b           385915 non-null   float64
#  25  bleedFavTmFbk-1a           385915 non-null   float64
#  26  bleedFavTmFbk-1b           385915 non-null   float64
#  27  bleedFavTmFbk-2b           385915 non-null   float64
#  28  bleedHprsovCmdStatus-1a    772075 non-null   float64
#  29  bleedHprsovCmdStatus-1b    772075 non-null   float64
#  30  bleedHprsovCmdStatus-2a    772075 non-null   float64
#  31  bleedHprsovCmdStatus-2b    772075 non-null   float64
#  32  bleedHprsovOpPosStatus-1a  772075 non-null   float64
#  33  bleedHprsovOpPosStatus-1b  772075 non-null   float64
#  34  bleedHprsovOpPosStatus-2a  772075 non-null   float64
#  35  bleedHprsovOpPosStatus-2b  772075 non-null   float64
#  36  bleedMonPress-1a           385915 non-null   float64
#  37  bleedMonPress-1b           385915 non-null   float64
#  38  bleedMonPress-2a           385915 non-null   float64
#  39  bleedMonPress-2b           385915 non-null   float64
#  40  bleedOnStatus-1a           772075 non-null   float64
#  41  bleedOnStatus-1b           772075 non-null   float64
#  42  bleedOnStatus-2b           772075 non-null   float64
#  43  bleedOverpressCas-2a       385915 non-null   float64
#  44  bleedOverpressCas-2b       385915 non-null   float64
#  45  bleedPrecoolDiffPress-1a   385915 non-null   float64
#  46  bleedPrecoolDiffPress-1b   385915 non-null   float64
#  47  bleedPrecoolDiffPress-2a   385915 non-null   float64
#  48  bleedPrecoolDiffPress-2b   385915 non-null   float64
#  49  bleedPrsovClPosStatus-1a   772075 non-null   float64
#  50  bleedPrsovClPosStatus-2a   772075 non-null   float64
#  51  bleedPrsovFbk-1a           385915 non-null   float64
# dtypes: float64(51), int64(1)
# memory usage: 612.5 MB

# %%
flights_combined_data_083.describe()
# Out:
#        recording_time     dateDay-1   dateMonth-1    dateYear-1
# count    1.543896e+06  77189.000000  77189.000000  77189.000000  \
# mean     3.110275e+06     15.325124      6.342601   2022.514309
# std      2.220861e+06     11.693691      5.497783      0.499798
# min      0.000000e+00      1.000000      1.000000   2022.000000
# 25%      1.288450e+06      3.000000      1.000000   2022.000000
# 50%      2.757400e+06     10.000000      1.000000   2023.000000
# 75%      4.408150e+06     27.000000     12.000000   2023.000000
# max      9.268000e+06     29.000000     12.000000   2023.000000
#
#        phaseOfFlight-1  message0418DAA-1  message0422DAA-1
# count    772075.000000           77189.0           77189.0  \
# mean          0.873945               0.0               0.0
# std           0.801437               0.0               0.0
# min           0.000000               0.0               0.0
# 25%           0.000000               0.0               0.0
# 50%           1.000000               0.0               0.0
# 75%           2.000000               0.0               0.0
# max           2.000000               0.0               0.0
#
#        amscHprsovDrivF-1a  amscHprsovDrivF-1b  amscHprsovDrivF-2b  ...
# count            385915.0            385915.0            385915.0  ...  \
# mean                  0.0                 0.0                 0.0  ...
# std                   0.0                 0.0                 0.0  ...
# min                   0.0                 0.0                 0.0  ...
# 25%                   0.0                 0.0                 0.0  ...
# 50%                   0.0                 0.0                 0.0  ...
# 75%                   0.0                 0.0                 0.0  ...
# max                   0.0                 0.0                 0.0  ...
#
#        bleedOnStatus-2b  bleedOverpressCas-2a  bleedOverpressCas-2b
# count     772075.000000              385915.0              385915.0  \
# mean           0.912044                   0.0                   0.0
# std            0.283232                   0.0                   0.0
# min            0.000000                   0.0                   0.0
# 25%            1.000000                   0.0                   0.0
# 50%            1.000000                   0.0                   0.0
# 75%            1.000000                   0.0                   0.0
# max            1.000000                   0.0                   0.0
#
#        bleedPrecoolDiffPress-1a  bleedPrecoolDiffPress-1b
# count             385915.000000             385915.000000  \
# mean                   0.635461                  0.635682
# std                    0.306714                  0.307086
# min                   -0.250000                 -0.250000
# 25%                    0.531250                  0.531250
# 50%                    0.625000                  0.625000
# 75%                    0.750000                  0.750000
# max                    3.375000                  4.500000
#
#        bleedPrecoolDiffPress-2a  bleedPrecoolDiffPress-2b
# count             385915.000000             385915.000000  \
# mean                   0.536090                  0.536088
# std                    0.258454                  0.258465
# min                   -0.218750                 -0.218750
# 25%                    0.437500                  0.437500
# 50%                    0.531250                  0.531250
# 75%                    0.656250                  0.656250
# max                    3.156250                  3.156250
#
#        bleedPrsovClPosStatus-1a  bleedPrsovClPosStatus-2a  bleedPrsovFbk-1a
# count             772075.000000             772075.000000     385915.000000
# mean                   0.065622                  0.087958        129.576876
# std                    0.247620                  0.283234         84.134783
# min                    0.000000                  0.000000          0.000000
# 25%                    0.000000                  0.000000          0.375000
# 50%                    0.000000                  0.000000        175.250000
# 75%                    0.000000                  0.000000        187.000000
# max                    1.000000                  1.000000        307.625000
#
# [8 rows x 52 columns]

# %%
flights_combined_data_083.shape
# Out:
# (1543896, 52)

# %%
def convert_columns(df_filtered):
    for coluna in df_filtered.columns:
        if df_filtered[coluna].dtype == 'float64':
            df_filtered[coluna] = df_filtered[coluna].astype('float32')

        if df_filtered[coluna].dtype == 'int64':
            df_filtered[coluna] = df_filtered[coluna].astype('int32')

    return df_filtered

# %%
flights_combined_data_083 = convert_columns(flights_combined_data_083)
# Out:
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('int32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_32932\3502086845.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[coluna] = df_filtered[coluna].astype('float32')

# %%
flights_combined_data_083
# Out:
#          recording_time  dateDay-1  dateMonth-1  dateYear-1  phaseOfFlight-1
# 0                     0        NaN          NaN         NaN              0.0  \
# 1                    50        NaN          NaN         NaN              NaN
# 2                   100        NaN          NaN         NaN              0.0
# 3                   150       26.0         12.0      2022.0              NaN
# 4                   200        NaN          NaN         NaN              0.0
# ...                 ...        ...          ...         ...              ...
# 1543891         3555800        NaN          NaN         NaN              NaN
# 1543892         3555850        NaN          NaN         NaN              0.0
# 1543893         3555900        NaN          NaN         NaN              NaN
# 1543894         3555950        NaN          NaN         NaN              0.0
# 1543895         3556000        NaN          NaN         NaN              NaN
#
#          message0418DAA-1  message0422DAA-1  amscHprsovDrivF-1a
# 0                     NaN               NaN                 NaN  \
# 1                     NaN               NaN                 0.0
# 2                     NaN               NaN                 NaN
# 3                     0.0               0.0                 NaN
# 4                     NaN               NaN                 NaN
# ...                   ...               ...                 ...
# 1543891               NaN               NaN                 0.0
# 1543892               NaN               NaN                 NaN
# 1543893               NaN               NaN                 NaN
# 1543894               NaN               NaN                 NaN
# 1543895               NaN               NaN                 0.0
#
#          amscHprsovDrivF-1b  amscHprsovDrivF-2b  ...  bleedOnStatus-2b
# 0                       NaN                 NaN  ...               0.0  \
# 1                       0.0                 0.0  ...               NaN
# 2                       NaN                 NaN  ...               0.0
# 3                       NaN                 NaN  ...               NaN
# 4                       NaN                 NaN  ...               0.0
# ...                     ...                 ...  ...               ...
# 1543891                 0.0                 0.0  ...               NaN
# 1543892                 NaN                 NaN  ...               0.0
# 1543893                 NaN                 NaN  ...               NaN
# 1543894                 NaN                 NaN  ...               0.0
# 1543895                 0.0                 0.0  ...               NaN
#
#          bleedOverpressCas-2a  bleedOverpressCas-2b  bleedPrecoolDiffPress-1a
# 0                         NaN                   NaN                       NaN  \
# 1                         0.0                   0.0                   0.03125
# 2                         NaN                   NaN                       NaN
# 3                         NaN                   NaN                       NaN
# 4                         NaN                   NaN                       NaN
# ...                       ...                   ...                       ...
# 1543891                   0.0                   0.0                   0.06250
# 1543892                   NaN                   NaN                       NaN
# 1543893                   NaN                   NaN                       NaN
# 1543894                   NaN                   NaN                       NaN
# 1543895                   0.0                   0.0                   0.06250
#
#          bleedPrecoolDiffPress-1b  bleedPrecoolDiffPress-2a
# 0                             NaN                       NaN  \
# 1                         -0.0625                   0.00000
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 1543891                    0.0625                   0.03125
# 1543892                       NaN                       NaN
# 1543893                       NaN                       NaN
# 1543894                       NaN                       NaN
# 1543895                    0.0625                   0.03125
#
#          bleedPrecoolDiffPress-2b  bleedPrsovClPosStatus-1a
# 0                             NaN                       1.0  \
# 1                         0.00000                       NaN
# 2                             NaN                       1.0
# 3                             NaN                       NaN
# 4                             NaN                       1.0
# ...                           ...                       ...
# 1543891                   0.03125                       NaN
# 1543892                       NaN                       1.0
# 1543893                       NaN                       NaN
# 1543894                       NaN                       1.0
# 1543895                   0.03125                       NaN
#
#          bleedPrsovClPosStatus-2a  bleedPrsovFbk-1a
# 0                             1.0               NaN
# 1                             NaN             0.875
# 2                             1.0               NaN
# 3                             NaN               NaN
# 4                             1.0               NaN
# ...                           ...               ...
# 1543891                       NaN             0.750
# 1543892                       1.0               NaN
# 1543893                       NaN               NaN
# 1543894                       1.0               NaN
# 1543895                       NaN             0.750
#
# [1543896 rows x 52 columns]

# %%
flights_combined_data_083.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1543896 entries, 0 to 1543895
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   recording_time             1543896 non-null  int32
#  1   dateDay-1                  77189 non-null    float32
#  2   dateMonth-1                77189 non-null    float32
#  3   dateYear-1                 77189 non-null    float32
#  4   phaseOfFlight-1            772075 non-null   float32
#  5   message0418DAA-1           77189 non-null    float32
#  6   message0422DAA-1           77189 non-null    float32
#  7   amscHprsovDrivF-1a         385915 non-null   float32
#  8   amscHprsovDrivF-1b         385915 non-null   float32
#  9   amscHprsovDrivF-2b         385915 non-null   float32
#  10  amscPrsovDrivF-1a          385915 non-null   float32
#  11  amscPrsovDrivF-1b          385915 non-null   float32
#  12  amscPrsovDrivF-2b          385915 non-null   float32
#  13  basBleedLowPressF-1a       385915 non-null   float32
#  14  basBleedLowPressF-2b       385915 non-null   float32
#  15  basBleedLowTempF-1a        385915 non-null   float32
#  16  basBleedLowTempF-2b        385915 non-null   float32
#  17  basBleedOverPressF-1a      385915 non-null   float32
#  18  basBleedOverPressF-2b      385915 non-null   float32
#  19  basBleedOverTempF-1a       385915 non-null   float32
#  20  basBleedOverTempF-2b       385915 non-null   float32
#  21  bleedFavTmCmd-1a           385915 non-null   float32
#  22  bleedFavTmCmd-1b           385915 non-null   float32
#  23  bleedFavTmCmd-2a           385915 non-null   float32
#  24  bleedFavTmCmd-2b           385915 non-null   float32
#  25  bleedFavTmFbk-1a           385915 non-null   float32
#  26  bleedFavTmFbk-1b           385915 non-null   float32
#  27  bleedFavTmFbk-2b           385915 non-null   float32
#  28  bleedHprsovCmdStatus-1a    772075 non-null   float32
#  29  bleedHprsovCmdStatus-1b    772075 non-null   float32
#  30  bleedHprsovCmdStatus-2a    772075 non-null   float32
#  31  bleedHprsovCmdStatus-2b    772075 non-null   float32
#  32  bleedHprsovOpPosStatus-1a  772075 non-null   float32
#  33  bleedHprsovOpPosStatus-1b  772075 non-null   float32
#  34  bleedHprsovOpPosStatus-2a  772075 non-null   float32
#  35  bleedHprsovOpPosStatus-2b  772075 non-null   float32
#  36  bleedMonPress-1a           385915 non-null   float32
#  37  bleedMonPress-1b           385915 non-null   float32
#  38  bleedMonPress-2a           385915 non-null   float32
#  39  bleedMonPress-2b           385915 non-null   float32
#  40  bleedOnStatus-1a           772075 non-null   float32
#  41  bleedOnStatus-1b           772075 non-null   float32
#  42  bleedOnStatus-2b           772075 non-null   float32
#  43  bleedOverpressCas-2a       385915 non-null   float32
#  44  bleedOverpressCas-2b       385915 non-null   float32
#  45  bleedPrecoolDiffPress-1a   385915 non-null   float32
#  46  bleedPrecoolDiffPress-1b   385915 non-null   float32
#  47  bleedPrecoolDiffPress-2a   385915 non-null   float32
#  48  bleedPrecoolDiffPress-2b   385915 non-null   float32
#  49  bleedPrsovClPosStatus-1a   772075 non-null   float32
#  50  bleedPrsovClPosStatus-2a   772075 non-null   float32
#  51  bleedPrsovFbk-1a           385915 non-null   float32
# dtypes: float32(51), int32(1)
# memory usage: 306.3 MB

# %%
flights_combined_data_083.describe()
# Out:
#        recording_time     dateDay-1   dateMonth-1    dateYear-1
# count    1.543896e+06  77189.000000  77189.000000  77189.000000  \
# mean     3.110275e+06     15.325124      6.342601   2022.514526
# std      2.220861e+06     11.693690      5.497783      0.499798
# min      0.000000e+00      1.000000      1.000000   2022.000000
# 25%      1.288450e+06      3.000000      1.000000   2022.000000
# 50%      2.757400e+06     10.000000      1.000000   2023.000000
# 75%      4.408150e+06     27.000000     12.000000   2023.000000
# max      9.268000e+06     29.000000     12.000000   2023.000000
#
#        phaseOfFlight-1  message0418DAA-1  message0422DAA-1
# count    772075.000000           77189.0           77189.0  \
# mean          0.873945               0.0               0.0
# std           0.801437               0.0               0.0
# min           0.000000               0.0               0.0
# 25%           0.000000               0.0               0.0
# 50%           1.000000               0.0               0.0
# 75%           2.000000               0.0               0.0
# max           2.000000               0.0               0.0
#
#        amscHprsovDrivF-1a  amscHprsovDrivF-1b  amscHprsovDrivF-2b  ...
# count            385915.0            385915.0            385915.0  ...  \
# mean                  0.0                 0.0                 0.0  ...
# std                   0.0                 0.0                 0.0  ...
# min                   0.0                 0.0                 0.0  ...
# 25%                   0.0                 0.0                 0.0  ...
# 50%                   0.0                 0.0                 0.0  ...
# 75%                   0.0                 0.0                 0.0  ...
# max                   0.0                 0.0                 0.0  ...
#
#        bleedOnStatus-2b  bleedOverpressCas-2a  bleedOverpressCas-2b
# count     772075.000000              385915.0              385915.0  \
# mean           0.912044                   0.0                   0.0
# std            0.283232                   0.0                   0.0
# min            0.000000                   0.0                   0.0
# 25%            1.000000                   0.0                   0.0
# 50%            1.000000                   0.0                   0.0
# 75%            1.000000                   0.0                   0.0
# max            1.000000                   0.0                   0.0
#
#        bleedPrecoolDiffPress-1a  bleedPrecoolDiffPress-1b
# count             385915.000000             385915.000000  \
# mean                   0.635461                  0.635682
# std                    0.306715                  0.307086
# min                   -0.250000                 -0.250000
# 25%                    0.531250                  0.531250
# 50%                    0.625000                  0.625000
# 75%                    0.750000                  0.750000
# max                    3.375000                  4.500000
#
#        bleedPrecoolDiffPress-2a  bleedPrecoolDiffPress-2b
# count             385915.000000             385915.000000  \
# mean                   0.536090                  0.536088
# std                    0.258454                  0.258465
# min                   -0.218750                 -0.218750
# 25%                    0.437500                  0.437500
# 50%                    0.531250                  0.531250
# 75%                    0.656250                  0.656250
# max                    3.156250                  3.156250
#
#        bleedPrsovClPosStatus-1a  bleedPrsovClPosStatus-2a  bleedPrsovFbk-1a
# count             772075.000000             772075.000000     385915.000000
# mean                   0.065622                  0.087958        129.576874
# std                    0.247620                  0.283234         84.134781
# min                    0.000000                  0.000000          0.000000
# 25%                    0.000000                  0.000000          0.375000
# 50%                    0.000000                  0.000000        175.250000
# 75%                    0.000000                  0.000000        187.000000
# max                    1.000000                  1.000000        307.625000
#
# [8 rows x 52 columns]

# %%
flights_combined_data_083.to_parquet("flights_combined_data_083.parquet")
